# %%
import pandas as pd 
import glob
import matplotlib.pyplot as plt
import numpy as np

# %%
path_to_xlsx = 'C:\\Users\\nogas\\Image_data\\images_related_100_104.xlsx'

# %%
df = pd.read_excel(path_to_xlsx)

# %%
df
# Out:
#        Unnamed: 0                                             images  \
# 0               0  http://dev.sphaera.mpiwg-berlin.mpg.de/contain...
# 1               1  http://dev.sphaera.mpiwg-berlin.mpg.de/contain...
# 2               2  http://dev.sphaera.mpiwg-berlin.mpg.de/contain...
# 3               3  http://dev.sphaera.mpiwg-berlin.mpg.de/contain...
# 4               4  http://dev.sphaera.mpiwg-berlin.mpg.de/contain...
# ...           ...                                                ...
# 16233       20851  http://www.researchspace.org/ontology/ImageReg...
# 16234       20852  http://www.researchspace.org/ontology/ImageReg...
# 16235       20853  http://www.researchspace.org/ontology/ImageReg...
# 16236       20854  http://www.researchspace.org/ontology/ImageReg...
# 16237       20855  http://www.researchspace.org/ontology/ImageReg...
#
#                                                 keywords cluster_name   bid  \
# 0      CK_Relations Between the Spheres of the Sun an...    SIL_03326  1594
# 1      CK_08 Spheres;CK_Terraqueous Globe;CK_Parallel...    SIL_02440  1597
# 2      CK_Sphericity of the Heavens;MVK_Pictorial_Dia...    SIL_03167  1597
# 3      CK_Sphericity of the Water Element;CK_Terraque...    SIL_03188  1597
# 4      SK_2.8 Extended Uses of Sign;CK_Pyramid of a S...    SIL_00191  1597
# ...                                                  ...          ...   ...
# 16233  SK_3.10 Day and Night;CK_Movement of the Sun;M...    SIL_01897  2281
# 16234  SK_3.10 Day and Night;CK_Movement of the Sun;M...    SIL_01491  2281
# 16235  CK_Solar Eclipse;MVK_Pictorial_Diagrams;MTK_So...    SIL_03580  2281
# 16236  CK_Lunar Eclipse;MVK_Pictorial_Diagrams;MTK_Lu...    SIL_03550  2281
# 16237  CK_Lunar Phases;MVK_Pictorial_Diagrams;MTK_Lun...    SIL_03543  2281
#
#                                                     book  \
# 0      http://sphaera.mpiwg-berlin.mpg.de/id/item/8f5...
# 1      http://sphaera.mpiwg-berlin.mpg.de/id/item/ba1...
# 2      http://sphaera.mpiwg-berlin.mpg.de/id/item/ba1...
# 3      http://sphaera.mpiwg-berlin.mpg.de/id/item/ba1...
# 4      http://sphaera.mpiwg-berlin.mpg.de/id/item/ba1...
# ...                                                  ...
# 16233  http://sphaera.mpiwg-berlin.mpg.de/id/item/af4...
# 16234  http://sphaera.mpiwg-berlin.mpg.de/id/item/af4...
# 16235  http://sphaera.mpiwg-berlin.mpg.de/id/item/af4...
# 16236  http://sphaera.mpiwg-berlin.mpg.de/id/item/af4...
# 16237  http://sphaera.mpiwg-berlin.mpg.de/id/item/af4...
#
#                                         part_or_adaption  \
# 0      http://sphaera.mpiwg-berlin.mpg.de/id/adaption...
# 1      http://sphaera.mpiwg-berlin.mpg.de/id/part/524...
# 2      http://sphaera.mpiwg-berlin.mpg.de/id/part/524...
# 3      http://sphaera.mpiwg-berlin.mpg.de/id/part/524...
# 4      http://sphaera.mpiwg-berlin.mpg.de/id/part/524...
# ...                                                  ...
# 16233  http://sphaera.mpiwg-berlin.mpg.de/id/part/47c...
# 16234  http://sphaera.mpiwg-berlin.mpg.de/id/part/47c...
# 16235  http://sphaera.mpiwg-berlin.mpg.de/id/part/47c...
# 16236  http://sphaera.mpiwg-berlin.mpg.de/id/part/47c...
# 16237  http://sphaera.mpiwg-berlin.mpg.de/id/part/47c...
#
#            part_or_adaption_label  custom_identifier  pagenum  \
# 0            Tractatus de sphaera                291       27
# 1            Sphaera by P. Catena                311        5
# 2            Sphaera by P. Catena                311        7
# 3            Sphaera by P. Catena                311        9
# 4            Sphaera by P. Catena                311       16
# ...                           ...                ...      ...
# 16233  Compendium by P. Valeriano                251      333
# 16234  Compendium by P. Valeriano                251      334
# 16235  Compendium by P. Valeriano                251      340
# 16236  Compendium by P. Valeriano                251      341
# 16237  Compendium by P. Valeriano                251      343
#
#                              bb page_label  year
# 0          xywh=116,929,875,476        NaN   NaN
# 1      xywh=1944,1029,1376,1404        NaN   NaN
# 2        xywh=2028,1340,638,601        NaN   NaN
# 3      xywh=1950,1422,1104,1234        NaN   NaN
# 4        xywh=2172,1190,362,561        NaN   NaN
# ...                         ...        ...   ...
# 16233     xywh=569,1056,617,597        NaN   NaN
# 16234     xywh=439,1330,587,563        NaN   NaN
# 16235    xywh=460,276,1026,1504        NaN   NaN
# 16236    xywh=130,590,1067,1575        NaN   NaN
# 16237     xywh=281,570,866,1617        NaN   NaN
#
# [16238 rows x 13 columns]

# %%
path_to_xlsx1 = 'G:\\My Drive\\DataFiles\\Full_Image_List_6.5.24\\all_elements.xlsx'

# %%
df1 = pd.read_excel(path_to_xlsx1)

# %%
df1
# Out:
#        Unnamed: 0                                             images  \
# 0               0  http://devmeta.sphaera.mpiwg-berlin.mpg.de/res...
# 1               1  http://devmeta.sphaera.mpiwg-berlin.mpg.de/res...
# 2               2  http://devmeta.sphaera.mpiwg-berlin.mpg.de/res...
# 3               3  http://devmeta.sphaera.mpiwg-berlin.mpg.de/res...
# 4               4  http://devmeta.sphaera.mpiwg-berlin.mpg.de/res...
# ...           ...                                                ...
# 21176       21176  http://devmeta.sphaera.mpiwg-berlin.mpg.de/res...
# 21177       21177  http://devmeta.sphaera.mpiwg-berlin.mpg.de/res...
# 21178       21178  http://devmeta.sphaera.mpiwg-berlin.mpg.de/res...
# 21179       21179  http://devmeta.sphaera.mpiwg-berlin.mpg.de/res...
# 21180       21180  http://devmeta.sphaera.mpiwg-berlin.mpg.de/res...
#
#                                                 keywords cluster_name  \
# 0      CK_Relations Between the Spheres of the Sun an...    SIL_03326
# 1      MVK_Pictorial_Diagrams;CK_08 Spheres;CK_Terraq...    SIL_02440
# 2      CK_Sphericity of the Heavens;MVK_Pictorial_Dia...    SIL_03167
# 3      MVK_Pictorial_Illustrations;MTK_Sphericity of ...    SIL_03188
# 4      SK_2.8 Extended Uses of Sign;CK_Pyramid of a S...    SIL_00191
# ...                                                  ...          ...
# 21176  MVK_Pictorial_Diagrams;SK_4.4 Cause of lunar e...    SIL_00267
# 21177  CK_Solar Eclipse;MVK_Pictorial_Diagrams;MTK_So...    SIL_03580
# 21178  CK_Lunar Eclipse;MVK_Pictorial_Diagrams;MTK_Lu...    SIL_03550
# 21179  CK_Lunar Phases;MVK_Pictorial_Diagrams;MTK_Lun...    SIL_03543
# 21180  MVK_Pictorial_Illustrations;SK_4.4 Cause of lu...    SIL_00261
#
#                                                  authors  \
# 0                Sacrobosco, Johannes de;Beyer, Hartmann
# 1                                         Catena, Pietro
# 2                                         Catena, Pietro
# 3                                         Catena, Pietro
# 4                                         Catena, Pietro
# ...                                                  ...
# 21176  Sacrobosco, Johannes de;Vinet, Élie;Hero, Albe...
# 21177  Sacrobosco, Johannes de;Vinet, Élie;Hero, Albe...
# 21178  Sacrobosco, Johannes de;Vinet, Élie;Hero, Albe...
# 21179  Sacrobosco, Johannes de;Vinet, Élie;Hero, Albe...
# 21180  Vinet, Élie;Sacrobosco, Johannes de;Hero, Albe...
#
#                             publishers                         printers  \
# 0      Company Heirs of Peter I. Seitz  Company Heirs of Peter I. Seitz
# 1                  Percacino, Grazioso              Percacino, Grazioso
# 2                  Percacino, Grazioso              Percacino, Grazioso
# 3                  Percacino, Grazioso              Percacino, Grazioso
# 4                  Percacino, Grazioso              Percacino, Grazioso
# ...                                ...                              ...
# 21176                    Bellère, Jean                    Bellère, Jean
# 21177                    Bellère, Jean                    Bellère, Jean
# 21178                    Bellère, Jean                    Bellère, Jean
# 21179                    Bellère, Jean                    Bellère, Jean
# 21180                    Bellère, Jean                    Bellère, Jean
#
#             place  year   bid  \
# 0      Wittenberg  1550  1594
# 1           Padua  1561  1597
# 2           Padua  1561  1597
# 3           Padua  1561  1597
# 4           Padua  1561  1597
# ...           ...   ...   ...
# 21176     Antwerp  1582  2281
# 21177     Antwerp  1582  2281
# 21178     Antwerp  1582  2281
# 21179     Antwerp  1582  2281
# 21180     Antwerp  1582  2281
#
#                                                     book  \
# 0      http://sphaera.mpiwg-berlin.mpg.de/id/item/8f5...
# 1      http://sphaera.mpiwg-berlin.mpg.de/id/item/ba1...
# 2      http://sphaera.mpiwg-berlin.mpg.de/id/item/ba1...
# 3      http://sphaera.mpiwg-berlin.mpg.de/id/item/ba1...
# 4      http://sphaera.mpiwg-berlin.mpg.de/id/item/ba1...
# ...                                                  ...
# 21176  http://sphaera.mpiwg-berlin.mpg.de/id/item/af4...
# 21177  http://sphaera.mpiwg-berlin.mpg.de/id/item/af4...
# 21178  http://sphaera.mpiwg-berlin.mpg.de/id/item/af4...
# 21179  http://sphaera.mpiwg-berlin.mpg.de/id/item/af4...
# 21180  http://sphaera.mpiwg-berlin.mpg.de/id/item/af4...
#
#                                         part_or_adaption  \
# 0      http://sphaera.mpiwg-berlin.mpg.de/id/adaption...
# 1      http://sphaera.mpiwg-berlin.mpg.de/id/part/524...
# 2      http://sphaera.mpiwg-berlin.mpg.de/id/part/524...
# 3      http://sphaera.mpiwg-berlin.mpg.de/id/part/524...
# 4      http://sphaera.mpiwg-berlin.mpg.de/id/part/524...
# ...                                                  ...
# 21176  http://sphaera.mpiwg-berlin.mpg.de/id/part/47c...
# 21177  http://sphaera.mpiwg-berlin.mpg.de/id/part/47c...
# 21178  http://sphaera.mpiwg-berlin.mpg.de/id/part/47c...
# 21179  http://sphaera.mpiwg-berlin.mpg.de/id/part/47c...
# 21180  http://sphaera.mpiwg-berlin.mpg.de/id/part/47c...
#
#            part_or_adaption_label  pagenum                        bb
# 0            Tractatus de sphaera       27      xywh=116,929,875,476
# 1            Sphaera by P. Catena        5  xywh=1944,1029,1376,1404
# 2            Sphaera by P. Catena        7    xywh=2028,1340,638,601
# 3            Sphaera by P. Catena        9  xywh=1950,1422,1104,1234
# 4            Sphaera by P. Catena       16    xywh=2172,1190,362,561
# ...                           ...      ...                       ...
# 21176  Compendium by P. Valeriano      339      xywh=254,288,788,635
# 21177  Compendium by P. Valeriano      340    xywh=460,276,1026,1504
# 21178  Compendium by P. Valeriano      341    xywh=130,590,1067,1575
# 21179  Compendium by P. Valeriano      343     xywh=281,570,866,1617
# 21180  Compendium by P. Valeriano      344    xywh=435,930,1022,1034
#
# [21181 rows x 15 columns]

# %%
# Function to extract the identifier from the URL
def extract_identifier(url):
    # Split the URL by '/' and return the last part
    return url.split('/')[-1]

# Create the identifier column in both dataframes
df['identifier'] = df['images'].apply(extract_identifier)
df1['identifier'] = df1['images'].apply(extract_identifier)

# %%
# Merge the dataframes on the identifier column
merged_df = pd.merge(df, df1, on='identifier', how='inner')

# Drop the identifier column if not needed
merged_df.drop(columns=['identifier'], inplace=True)

# %%
merged_df
# Out:
#        Unnamed: 0_x                                           images_x  \
# 0                 0  http://dev.sphaera.mpiwg-berlin.mpg.de/contain...
# 1                 1  http://dev.sphaera.mpiwg-berlin.mpg.de/contain...
# 2                 2  http://dev.sphaera.mpiwg-berlin.mpg.de/contain...
# 3                 3  http://dev.sphaera.mpiwg-berlin.mpg.de/contain...
# 4                 4  http://dev.sphaera.mpiwg-berlin.mpg.de/contain...
# ...             ...                                                ...
# 16811         20851  http://www.researchspace.org/ontology/ImageReg...
# 16812         20852  http://www.researchspace.org/ontology/ImageReg...
# 16813         20853  http://www.researchspace.org/ontology/ImageReg...
# 16814         20854  http://www.researchspace.org/ontology/ImageReg...
# 16815         20855  http://www.researchspace.org/ontology/ImageReg...
#
#                                               keywords_x cluster_name_x  \
# 0      CK_Relations Between the Spheres of the Sun an...      SIL_03326
# 1      CK_08 Spheres;CK_Terraqueous Globe;CK_Parallel...      SIL_02440
# 2      CK_Sphericity of the Heavens;MVK_Pictorial_Dia...      SIL_03167
# 3      CK_Sphericity of the Water Element;CK_Terraque...      SIL_03188
# 4      SK_2.8 Extended Uses of Sign;CK_Pyramid of a S...      SIL_00191
# ...                                                  ...            ...
# 16811  SK_3.10 Day and Night;CK_Movement of the Sun;M...      SIL_01897
# 16812  SK_3.10 Day and Night;CK_Movement of the Sun;M...      SIL_01491
# 16813  CK_Solar Eclipse;MVK_Pictorial_Diagrams;MTK_So...      SIL_03580
# 16814  CK_Lunar Eclipse;MVK_Pictorial_Diagrams;MTK_Lu...      SIL_03550
# 16815  CK_Lunar Phases;MVK_Pictorial_Diagrams;MTK_Lun...      SIL_03543
#
#        bid_x                                             book_x  \
# 0       1594  http://sphaera.mpiwg-berlin.mpg.de/id/item/8f5...
# 1       1597  http://sphaera.mpiwg-berlin.mpg.de/id/item/ba1...
# 2       1597  http://sphaera.mpiwg-berlin.mpg.de/id/item/ba1...
# 3       1597  http://sphaera.mpiwg-berlin.mpg.de/id/item/ba1...
# 4       1597  http://sphaera.mpiwg-berlin.mpg.de/id/item/ba1...
# ...      ...                                                ...
# 16811   2281  http://sphaera.mpiwg-berlin.mpg.de/id/item/af4...
# 16812   2281  http://sphaera.mpiwg-berlin.mpg.de/id/item/af4...
# 16813   2281  http://sphaera.mpiwg-berlin.mpg.de/id/item/af4...
# 16814   2281  http://sphaera.mpiwg-berlin.mpg.de/id/item/af4...
# 16815   2281  http://sphaera.mpiwg-berlin.mpg.de/id/item/af4...
#
#                                       part_or_adaption_x  \
# 0      http://sphaera.mpiwg-berlin.mpg.de/id/adaption...
# 1      http://sphaera.mpiwg-berlin.mpg.de/id/part/524...
# 2      http://sphaera.mpiwg-berlin.mpg.de/id/part/524...
# 3      http://sphaera.mpiwg-berlin.mpg.de/id/part/524...
# 4      http://sphaera.mpiwg-berlin.mpg.de/id/part/524...
# ...                                                  ...
# 16811  http://sphaera.mpiwg-berlin.mpg.de/id/part/47c...
# 16812  http://sphaera.mpiwg-berlin.mpg.de/id/part/47c...
# 16813  http://sphaera.mpiwg-berlin.mpg.de/id/part/47c...
# 16814  http://sphaera.mpiwg-berlin.mpg.de/id/part/47c...
# 16815  http://sphaera.mpiwg-berlin.mpg.de/id/part/47c...
#
#          part_or_adaption_label_x  custom_identifier  pagenum_x  ...  \
# 0            Tractatus de sphaera                291         27  ...
# 1            Sphaera by P. Catena                311          5  ...
# 2            Sphaera by P. Catena                311          7  ...
# 3            Sphaera by P. Catena                311          9  ...
# 4            Sphaera by P. Catena                311         16  ...
# ...                           ...                ...        ...  ...
# 16811  Compendium by P. Valeriano                251        333  ...
# 16812  Compendium by P. Valeriano                251        334  ...
# 16813  Compendium by P. Valeriano                251        340  ...
# 16814  Compendium by P. Valeriano                251        341  ...
# 16815  Compendium by P. Valeriano                251        343  ...
#
#                             publishers                         printers  \
# 0      Company Heirs of Peter I. Seitz  Company Heirs of Peter I. Seitz
# 1                  Percacino, Grazioso              Percacino, Grazioso
# 2                  Percacino, Grazioso              Percacino, Grazioso
# 3                  Percacino, Grazioso              Percacino, Grazioso
# 4                  Percacino, Grazioso              Percacino, Grazioso
# ...                                ...                              ...
# 16811                    Bellère, Jean                    Bellère, Jean
# 16812                    Bellère, Jean                    Bellère, Jean
# 16813                    Bellère, Jean                    Bellère, Jean
# 16814                    Bellère, Jean                    Bellère, Jean
# 16815                    Bellère, Jean                    Bellère, Jean
#
#             place  year_y bid_y  \
# 0      Wittenberg    1550  1594
# 1           Padua    1561  1597
# 2           Padua    1561  1597
# 3           Padua    1561  1597
# 4           Padua    1561  1597
# ...           ...     ...   ...
# 16811     Antwerp    1582  2281
# 16812     Antwerp    1582  2281
# 16813     Antwerp    1582  2281
# 16814     Antwerp    1582  2281
# 16815     Antwerp    1582  2281
#
#                                                   book_y  \
# 0      http://sphaera.mpiwg-berlin.mpg.de/id/item/8f5...
# 1      http://sphaera.mpiwg-berlin.mpg.de/id/item/ba1...
# 2      http://sphaera.mpiwg-berlin.mpg.de/id/item/ba1...
# 3      http://sphaera.mpiwg-berlin.mpg.de/id/item/ba1...
# 4      http://sphaera.mpiwg-berlin.mpg.de/id/item/ba1...
# ...                                                  ...
# 16811  http://sphaera.mpiwg-berlin.mpg.de/id/item/af4...
# 16812  http://sphaera.mpiwg-berlin.mpg.de/id/item/af4...
# 16813  http://sphaera.mpiwg-berlin.mpg.de/id/item/af4...
# 16814  http://sphaera.mpiwg-berlin.mpg.de/id/item/af4...
# 16815  http://sphaera.mpiwg-berlin.mpg.de/id/item/af4...
#
#                                       part_or_adaption_y  \
# 0      http://sphaera.mpiwg-berlin.mpg.de/id/adaption...
# 1      http://sphaera.mpiwg-berlin.mpg.de/id/part/524...
# 2      http://sphaera.mpiwg-berlin.mpg.de/id/part/524...
# 3      http://sphaera.mpiwg-berlin.mpg.de/id/part/524...
# 4      http://sphaera.mpiwg-berlin.mpg.de/id/part/524...
# ...                                                  ...
# 16811  http://sphaera.mpiwg-berlin.mpg.de/id/part/47c...
# 16812  http://sphaera.mpiwg-berlin.mpg.de/id/part/47c...
# 16813  http://sphaera.mpiwg-berlin.mpg.de/id/part/47c...
# 16814  http://sphaera.mpiwg-berlin.mpg.de/id/part/47c...
# 16815  http://sphaera.mpiwg-berlin.mpg.de/id/part/47c...
#
#          part_or_adaption_label_y pagenum_y                      bb_y
# 0            Tractatus de sphaera        27      xywh=116,929,875,476
# 1            Sphaera by P. Catena         5  xywh=1944,1029,1376,1404
# 2            Sphaera by P. Catena         7    xywh=2028,1340,638,601
# 3            Sphaera by P. Catena         9  xywh=1950,1422,1104,1234
# 4            Sphaera by P. Catena        16    xywh=2172,1190,362,561
# ...                           ...       ...                       ...
# 16811  Compendium by P. Valeriano       333     xywh=569,1056,617,597
# 16812  Compendium by P. Valeriano       334     xywh=439,1330,587,563
# 16813  Compendium by P. Valeriano       340    xywh=460,276,1026,1504
# 16814  Compendium by P. Valeriano       341    xywh=130,590,1067,1575
# 16815  Compendium by P. Valeriano       343     xywh=281,570,866,1617
#
# [16816 rows x 28 columns]

# %%
#number of images printed by 20 year intervals

# Step 1: Group and count unique images by 20-year intervals
intervals = pd.cut(merged_df['year_y'], bins=range(1470, 1650, 20), right=False)
interval_count_images = df.groupby(intervals, observed=False)['images'].nunique()

# Step 2: Plotting
plt.figure(figsize=(10, 6))
plt.bar(interval_count_images.index.astype(str), interval_count_images.values, width=0.8, align='center')
plt.title('Number of Printed Images')
plt.xlabel('20-Year Intervals')
plt.ylabel('Number of Unique Images')
plt.xticks(rotation=45)
plt.grid(axis='y')

plt.tight_layout()
plt.show()

# %%
#image per book over the years

# Define the 20-year intervals based on 'year'
merged_df['year_interval'] = pd.cut(merged_df['year_y'], bins=range(1470, 1650, 20), right=False)

# Calculate number of unique images and books per interval
interval_counts = merged_df.groupby('year_interval').agg({
    'images_x': 'nunique',
    'book_x': 'nunique'
}).rename(columns={'images_x': 'unique_images', 'book_x': 'unique_books'})

# Calculate the ratio of unique images to unique books
interval_counts['image_to_book_ratio'] = interval_counts['unique_images'] / interval_counts['unique_books']

# Plotting the ratio
plt.figure(figsize=(10, 6))
plt.plot(interval_counts.index.astype(str), interval_counts['image_to_book_ratio'], marker='o', linestyle='-', color='b')
plt.title('Number of Images per Book')
plt.xlabel('20-Year Intervals')
plt.ylabel('Image to Book Ratio')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\nogas\AppData\Local\Temp\ipykernel_23060\33743065.py:7: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   interval_counts = merged_df.groupby('year_interval').agg({
