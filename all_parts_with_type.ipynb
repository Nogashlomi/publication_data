# %%
import practicalSPARQL
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import practicalSPARQL
import numpy as np
from collections import Counter
import practicalSPARQL

# %%
root_q = 'queries'
root_d = 'results'

# read login data
login = pd.read_json('dissertation/config_sparql.json')
ENDPOINT = login['endpoint'][0]
USERNAME = login['username'][0]
PASSWORD = login['password'][0]

# create sparql object
sparql = practicalSPARQL.practicalWrapper(ENDPOINT)
sparql.setCredentials(USERNAME, PASSWORD)

print("--- Querying ENDPOINT: {} ---".format(ENDPOINT))
# Out:
# --- Querying ENDPOINT: http://devmeta.sphaera.mpiwg-berlin.mpg.de/sparql ---

# %%
q = practicalSPARQL.stringify_SPARQL('sparql_config/textparts_and_books_250724.sparql')    # select data from the ttl file as a dataframe
df = sparql.select_as_dataframe(q)

# %%
df
# Out:
#                                                    book  \
# 0     http://sphaera.mpiwg-berlin.mpg.de/id/item/8f5...
# 1     http://sphaera.mpiwg-berlin.mpg.de/id/item/8f5...
# 2     http://sphaera.mpiwg-berlin.mpg.de/id/item/8f5...
# 3     http://sphaera.mpiwg-berlin.mpg.de/id/item/ba1...
# 4     http://sphaera.mpiwg-berlin.mpg.de/id/item/ba1...
# ...                                                 ...
# 2724  http://sphaera.mpiwg-berlin.mpg.de/id/item/af4...
# 2725  http://sphaera.mpiwg-berlin.mpg.de/id/item/af4...
# 2726  http://sphaera.mpiwg-berlin.mpg.de/id/item/af4...
# 2727  http://sphaera.mpiwg-berlin.mpg.de/id/item/af4...
# 2728  http://sphaera.mpiwg-berlin.mpg.de/id/item/af4...
#
#                                              book_label   bid  \
# 0     Quaestiones novae in libellum de sphaera Johan...  1594
# 1     Quaestiones novae in libellum de sphaera Johan...  1594
# 2     Quaestiones novae in libellum de sphaera Johan...  1594
# 3                                  Sphaera Petri Catena  1597
# 4                                  Sphaera Petri Catena  1597
# ...                                                 ...   ...
# 2724            Sphaera Ioannis de Sacro Bosco emendata  2281
# 2725            Sphaera Ioannis de Sacro Bosco emendata  2281
# 2726            Sphaera Ioannis de Sacro Bosco emendata  2281
# 2727            Sphaera Ioannis de Sacro Bosco emendata  2281
# 2728            Sphaera Ioannis de Sacro Bosco emendata  2281
#
#      custom_identifier                                              label  \
# 0                  100                               Tractatus de sphaera
# 1                  240  Paratext: Dedication letter to Anton Müller by...
# 2                  291                               Tractatus de sphaera
# 3                  100                               Tractatus de sphaera
# 4                  310  Paratext: Dedication letter of P. Catena to th...
# ...                ...                                                ...
# 2724               377                              Elements of Astronomy
# 2725               415  On Climate Zones by Nunes and translated into ...
# 2726               434                                           Almagest
# 2727               938  Vinet 1569 - Commentary on Treatise on the Sph...
# 2728               940  Giuntini's and new Vinet's commentary on the S...
#
#                                                 subject  \
# 0     http://sphaera.mpiwg-berlin.mpg.de/id/part/c61...
# 1     http://sphaera.mpiwg-berlin.mpg.de/id/part/ec2...
# 2     http://sphaera.mpiwg-berlin.mpg.de/id/adaption...
# 3     http://sphaera.mpiwg-berlin.mpg.de/id/part/c61...
# 4     http://sphaera.mpiwg-berlin.mpg.de/id/part/44d...
# ...                                                 ...
# 2724  http://sphaera.mpiwg-berlin.mpg.de/id/adaption...
# 2725  http://sphaera.mpiwg-berlin.mpg.de/id/adaption...
# 2726  http://sphaera.mpiwg-berlin.mpg.de/id/part/591...
# 2727  http://sphaera.mpiwg-berlin.mpg.de/id/adaption...
# 2728  http://sphaera.mpiwg-berlin.mpg.de/id/adaption...
#
#                                                   title  \
# 0                                  Tractatus de sphaera
# 1     Magnae pietatis et eruditionis viro D. Antonio...
# 2                                                &nbsp;
# 3                                  Tractatus de sphaera
# 4     Divae iustinae eximiae pietatis monachis, bona...
# ...                                                 ...
# 2724                    Liber de aggregatione stellarum
# 2725  On Climate Zones by Nunes and translated into ...
# 2726                                Mαθηματική σύνταξις
# 2727   Ioannis de Sacro Bosco proemium in suam Sphaeram
# 2728  Ioannis de Sacro Bosco Prooemium in suam sphaeram
#
#                      period  \
# 0          Late Middle Ages
# 1     Early Modern Period-2
# 2     Early Modern Period-2
# 3          Late Middle Ages
# 4     Early Modern Period-2
# ...                     ...
# 2724      Early Middle Ages
# 2725  Early Modern Period-2
# 2726              Antiquity
# 2727  Early Modern Period-2
# 2728  Early Modern Period-2
#
#                                        part_type_labels      dataset_labels  \
# 0                                Original Part, Content  Sphaera Sacrobosco
# 1           Original Part, Paratext – Dedication Letter  Sphaera Sacrobosco
# 2                                    Annotated, Content  Sphaera Sacrobosco
# 3                                Original Part, Content  Sphaera Sacrobosco
# 4     Original Part, Paratext – Letter to the reader...  Sphaera Sacrobosco
# ...                                                 ...                 ...
# 2724                               Translation, Content  Sphaera Sacrobosco
# 2725                               Translation, Content  Sphaera Sacrobosco
# 2726                             Original Part, Content  Sphaera Sacrobosco
# 2727                                 Annotated, Content  Sphaera Sacrobosco
# 2728                                 Annotated, Content  Sphaera Sacrobosco
#
#      corpora_labels
# 0      S. Tractatus
# 1      S. Tractatus
# 2      S. Tractatus
# 3      S. Tractatus
# 4      S. Tractatus
# ...             ...
# 2724   S. Tractatus
# 2725   S. Tractatus
# 2726   S. Tractatus
# 2727   S. Tractatus
# 2728   S. Tractatus
#
# [2729 rows x 11 columns]

# %%
# Assuming your DataFrame is called `df` and it has columns `book` and `custom_identifier`
unique_books_with_100 = df[df['custom_identifier'] == '100']['book'].nunique()

# Output the result
print(f"Number of unique books with custom identifier 100: {unique_books_with_100}")
# Out:
# Number of unique books with custom identifier 100: 359

# %%
# Assuming your DataFrame is called `df` and it has columns `book` and `custom_identifier`
unique_books_with_104 = df[df['custom_identifier'] == '104']['book'].nunique()

# Output the result
print(f"Number of unique books with custom identifier 104: {unique_books_with_104}")
# Out:
# Number of unique books with custom identifier 104: 20

# %%
q = practicalSPARQL.stringify_SPARQL('sparql_config/books_query.sparql')    # select data from the ttl file as a dataframe
books = sparql.select_as_dataframe(q)

# %%
# # Count the number of unique values in the column
# unique_count = df['book'].nunique()

# # Print the count of unique values
# print(f'The number of unique book values: {unique_count}')

# # Count the number of unique values in the column
# unique_count = df['custom_identifier'].nunique()

# # Print the count of unique values
# print(f'The number of unique part type custom_identifier values: {unique_count}')

# %%
#all adaption of 100
q = practicalSPARQL.stringify_SPARQL('sparql_config/adaptions_100.sparql')
df_adaptions_100 = sparql.select_as_dataframe(q)

# %%
#all influenced by 100
q = practicalSPARQL.stringify_SPARQL('sparql_config/influenced_100.sparql')
df_influenced_100 = sparql.select_as_dataframe(q)

# %%
#all adaption of 104
q = practicalSPARQL.stringify_SPARQL('sparql_config/adaptions_104.sparql')
df_adaptions_104 = sparql.select_as_dataframe(q)

# %%
#all influenced by 104
q = practicalSPARQL.stringify_SPARQL('sparql_config/Influenced_104.sparql')
df_influenced_104 = sparql.select_as_dataframe(q)

# %%
print(df_adaptions_104["custom_identifier"].unique())
# Out:
# ['277' '297' '320' '349' '424' '6002' '6005' '6004' '6010' '6003' '6012'
#  '6013' '6001' '6009' '6007' '6000']

# %%
print(df_influenced_104["custom_identifier"].unique())
# Out:
# ['6015']

# %%
# Assuming df is your main DataFrame and the other DataFrames are named accordingly
# Extract sets of unique identifiers from each DataFrame
adaptions_100_set = set(df_adaptions_100['custom_identifier'])
adaptions_104_set = set(df_adaptions_104['custom_identifier'])
influenced_100_set = set(df_influenced_100['custom_identifier'])
influenced_104_set = set(df_influenced_104['custom_identifier'])

# Create a new column 'part_type' and initialize with 'other'
df['part_type'] = 'other'

# Define a function to determine 'part_type'
def determine_part_type(identifier):
    if identifier == '100':
        return '100'
    elif identifier == '104':
        return '104'
    elif identifier in adaptions_100_set:
        return 'adaption_100'
    elif identifier in adaptions_104_set:
        return 'adaption_104'
    elif identifier in influenced_100_set:
        return 'influenced_100'
    elif identifier in influenced_104_set:
        return 'influenced_104'
    else:
        return 'other'

# Apply the function to the 'custom_identifier' column
df['part_type'] = df['custom_identifier'].apply(determine_part_type)

# %%
# Step 1: Check for common and non-common bid values
common_bids = df['bid'].isin(books['bid'])

# Identify non-common bids in df and books
non_common_bids_df = df[~common_bids]
non_common_bids_books = books[~books['bid'].isin(df['bid'])]

# Print non-common bids (if any)
print("Non-common bids in 'df':")
print(non_common_bids_df[['bid']])
print("Non-common bids in 'books':")
print(non_common_bids_books[['bid']])

# Step 2: Merge the DataFrames on 'bid'
part_type_books = pd.merge(df[['bid', 'part_type']], books[['bid', 'year', 'place']], on='bid', how='inner')
part_type_books
# Out:
# Non-common bids in 'df':
# Empty DataFrame
# Columns: [bid]
# Index: []
# Non-common bids in 'books':
# Empty DataFrame
# Columns: [bid]
# Index: []
#        bid     part_type  year       place
# 0     1594           100  1550  Wittenberg
# 1     1594         other  1550  Wittenberg
# 2     1594  adaption_100  1550  Wittenberg
# 3     1597           100  1561       Padua
# 4     1597         other  1561       Padua
# ...    ...           ...   ...         ...
# 2724  2281         other  1582     Antwerp
# 2725  2281         other  1582     Antwerp
# 2726  2281         other  1582     Antwerp
# 2727  2281  adaption_100  1582     Antwerp
# 2728  2281  adaption_100  1582     Antwerp
#
# [2729 rows x 4 columns]

# %%
# Ensure the 'year' column is numeric, handling any errors (e.g., converting non-numeric values to NaN)
part_type_books['year'] = pd.to_numeric(part_type_books['year'])

# Define bins and labels for the 20-year intervals
bins = [1470, 1490, 1510, 1530, 1550, 1570, 1590, 1610, 1630, 1650]
labels = ['1470-1489', '1490-1509', '1510-1529', '1530-1549', '1550-1569', '1570-1589', '1590-1609', '1610-1629', '1630-1649']

# Add the 'interval' column to the existing DataFrame, without dropping any other columns
part_type_books['interval'] = pd.cut(part_type_books['year'], bins=bins, labels=labels, right=False)
part_type_books
# Out:
#        bid     part_type  year       place   interval
# 0     1594           100  1550  Wittenberg  1550-1569
# 1     1594         other  1550  Wittenberg  1550-1569
# 2     1594  adaption_100  1550  Wittenberg  1550-1569
# 3     1597           100  1561       Padua  1550-1569
# 4     1597         other  1561       Padua  1550-1569
# ...    ...           ...   ...         ...        ...
# 2724  2281         other  1582     Antwerp  1570-1589
# 2725  2281         other  1582     Antwerp  1570-1589
# 2726  2281         other  1582     Antwerp  1570-1589
# 2727  2281  adaption_100  1582     Antwerp  1570-1589
# 2728  2281  adaption_100  1582     Antwerp  1570-1589
#
# [2729 rows x 5 columns]

# %%
# Calculate total unique 'bid' values per interval in the entire part_type_books DataFrame (before filtering)
total_unique_bids = part_type_books.groupby('interval')['bid'].nunique().reset_index()

# Filter out 'other' part_type in the part_type_books DataFrame
part_type_books_filtered = part_type_books[part_type_books['part_type'] != 'other']

# Group the filtered data by 'interval' and 'part_type', then count unique 'bid' values
unique_bids = part_type_books_filtered.groupby(['interval', 'part_type'])['bid'].nunique().reset_index()

# Pivot the data to get 'part_type' as columns, and 'interval' as rows
pivot_data = unique_bids.pivot(index='interval', columns='part_type', values='bid')

# Merge total unique bids data (before filtering) to align intervals
total_bids_pivot = total_unique_bids.set_index('interval')['bid']

# Plotting
plt.figure(figsize=(10, 6))

# Plot the unique bids per part type (filtered by excluding 'other')
pivot_data.plot(kind='line', marker='o', linestyle='-', figsize=(10, 6))

# Plot the total unique bids per interval (before filtering)
total_bids_pivot.plot(kind='line', marker='x', linestyle='--', color='black', label='Total Unique Bids')

# Adding labels and title
plt.title('Number of books that include a part type')
plt.xlabel('Year Interval')
plt.ylabel('Number of Unique Bids')
plt.legend(title='Part Type', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to make room for legend

# Show the plot
plt.show()
# Out:
# C:\Users\nogas\AppData\Local\Temp\ipykernel_7060\2579114293.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   total_unique_bids = part_type_books.groupby('interval')['bid'].nunique().reset_index()
# C:\Users\nogas\AppData\Local\Temp\ipykernel_7060\2579114293.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   unique_bids = part_type_books_filtered.groupby(['interval', 'part_type'])['bid'].nunique().reset_index()

# %%
import pandas as pd

# Ensure the 'year' column is numeric, handling any errors (e.g., converting non-numeric values to NaN)
part_type_books['year'] = pd.to_numeric(part_type_books['year'], errors='coerce')

# Optionally, drop rows with NaN values in the 'year' column (if any)
part_type_books = part_type_books.dropna(subset=['year'])

# Define bins and labels
bins = [1470, 1490, 1510, 1530, 1550, 1570, 1590, 1610, 1630, 1650]
labels = ['1470-1489', '1490-1509', '1510-1529', '1530-1549', '1550-1569', '1570-1589', '1590-1609', '1610-1629', '1630-1649']

# Assign each row to an interval based on the 'year' column
part_type_books['interval'] = pd.cut(part_type_books['year'], bins=bins, labels=labels, right=False)

# Group by 'part_type' and 'interval' and count the number of unique 'bid' values for each group
part_types_data = part_type_books.groupby(['part_type', 'interval']).agg(
    unique_bids=('bid', 'nunique')  # Count the unique 'bid' values in each group
).reset_index()

part_types_data
# Out:
# C:\Users\nogas\AppData\Local\Temp\ipykernel_7060\519253060.py:17: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   part_types_data = part_type_books.groupby(['part_type', 'interval']).agg(
#          part_type   interval  unique_bids
# 0              100  1470-1489           14
# 1              100  1490-1509           37
# 2              100  1510-1529           30
# 3              100  1530-1549           48
# 4              100  1550-1569           88
# 5              100  1570-1589           69
# 6              100  1590-1609           45
# 7              100  1610-1629           23
# 8              100  1630-1649            4
# 9              104  1470-1489            3
# 10             104  1490-1509            6
# 11             104  1510-1529            6
# 12             104  1530-1549            2
# 13             104  1550-1569            1
# 14             104  1570-1589            2
# 15             104  1590-1609            0
# 16             104  1610-1629            0
# 17             104  1630-1649            0
# 18    adaption_100  1470-1489            1
# 19    adaption_100  1490-1509           29
# 20    adaption_100  1510-1529           26
# 21    adaption_100  1530-1549           29
# 22    adaption_100  1550-1569           48
# 23    adaption_100  1570-1589           30
# 24    adaption_100  1590-1609           24
# 25    adaption_100  1610-1629           13
# 26    adaption_100  1630-1649            2
# 27    adaption_104  1470-1489            0
# 28    adaption_104  1490-1509            2
# 29    adaption_104  1510-1529            3
# 30    adaption_104  1530-1549            2
# 31    adaption_104  1550-1569            1
# 32    adaption_104  1570-1589            2
# 33    adaption_104  1590-1609            0
# 34    adaption_104  1610-1629            0
# 35    adaption_104  1630-1649            0
# 36  influenced_100  1470-1489            0
# 37  influenced_100  1490-1509            0
# 38  influenced_100  1510-1529            1
# 39  influenced_100  1530-1549            8
# 40  influenced_100  1550-1569           48
# 41  influenced_100  1570-1589           44
# 42  influenced_100  1590-1609           25
# 43  influenced_100  1610-1629           13
# 44  influenced_100  1630-1649            1
# 45           other  1470-1489            7
# 46           other  1490-1509           29
# 47           other  1510-1529           27
# 48           other  1530-1549           48
# 49           other  1550-1569           88
# 50           other  1570-1589           69
# 51           other  1590-1609           45
# 52           other  1610-1629           23
# 53           other  1630-1649            4

# %%
# #create a table with all the part and adaptions IDs and their book and part type

# all_treatises_editions_book_type = df[['custom_identifier', 'bid', 'part_type']]
# all_treatises_editions_book_type

# %%
# # Print the number of unique values in 'column_name'
# num_unique_treatises_editions = all_treatises_editions_book_type['custom_identifier'].nunique()
# print(num_unique_treatises_editions)

# number_unique_books = all_treatises_editions_book_type['bid'].nunique()
# print(number_unique_books)

# number_unique_part_type = all_treatises_editions_book_type['part_type'].unique()
# print(number_unique_part_type)

# %%
#all_treatises_editions_book_type.to_excel('treatises_books_part_types.xlsx')

# %%
# Merge the DataFrames on 'bid'
df = df.merge(all_books[['bid', 'year', 'place']], how='left', on='bid')

# %%
df
# Out:
#                                                    book  \
# 0     http://sphaera.mpiwg-berlin.mpg.de/id/item/8f5...
# 1     http://sphaera.mpiwg-berlin.mpg.de/id/item/8f5...
# 2     http://sphaera.mpiwg-berlin.mpg.de/id/item/8f5...
# 3     http://sphaera.mpiwg-berlin.mpg.de/id/item/ba1...
# 4     http://sphaera.mpiwg-berlin.mpg.de/id/item/ba1...
# ...                                                 ...
# 2724  http://sphaera.mpiwg-berlin.mpg.de/id/item/af4...
# 2725  http://sphaera.mpiwg-berlin.mpg.de/id/item/af4...
# 2726  http://sphaera.mpiwg-berlin.mpg.de/id/item/af4...
# 2727  http://sphaera.mpiwg-berlin.mpg.de/id/item/af4...
# 2728  http://sphaera.mpiwg-berlin.mpg.de/id/item/af4...
#
#                                              book_label   bid  \
# 0     Quaestiones novae in libellum de sphaera Johan...  1594
# 1     Quaestiones novae in libellum de sphaera Johan...  1594
# 2     Quaestiones novae in libellum de sphaera Johan...  1594
# 3                                  Sphaera Petri Catena  1597
# 4                                  Sphaera Petri Catena  1597
# ...                                                 ...   ...
# 2724            Sphaera Ioannis de Sacro Bosco emendata  2281
# 2725            Sphaera Ioannis de Sacro Bosco emendata  2281
# 2726            Sphaera Ioannis de Sacro Bosco emendata  2281
# 2727            Sphaera Ioannis de Sacro Bosco emendata  2281
# 2728            Sphaera Ioannis de Sacro Bosco emendata  2281
#
#      custom_identifier                                              label  \
# 0                  100                               Tractatus de sphaera
# 1                  240  Paratext: Dedication letter to Anton Müller by...
# 2                  291                               Tractatus de sphaera
# 3                  100                               Tractatus de sphaera
# 4                  310  Paratext: Dedication letter of P. Catena to th...
# ...                ...                                                ...
# 2724               377                              Elements of Astronomy
# 2725               415  On Climate Zones by Nunes and translated into ...
# 2726               434                                           Almagest
# 2727               938  Vinet 1569 - Commentary on Treatise on the Sph...
# 2728               940  Giuntini's and new Vinet's commentary on the S...
#
#                                                 subject  \
# 0     http://sphaera.mpiwg-berlin.mpg.de/id/part/c61...
# 1     http://sphaera.mpiwg-berlin.mpg.de/id/part/ec2...
# 2     http://sphaera.mpiwg-berlin.mpg.de/id/adaption...
# 3     http://sphaera.mpiwg-berlin.mpg.de/id/part/c61...
# 4     http://sphaera.mpiwg-berlin.mpg.de/id/part/44d...
# ...                                                 ...
# 2724  http://sphaera.mpiwg-berlin.mpg.de/id/adaption...
# 2725  http://sphaera.mpiwg-berlin.mpg.de/id/adaption...
# 2726  http://sphaera.mpiwg-berlin.mpg.de/id/part/591...
# 2727  http://sphaera.mpiwg-berlin.mpg.de/id/adaption...
# 2728  http://sphaera.mpiwg-berlin.mpg.de/id/adaption...
#
#                                                   title  \
# 0                                  Tractatus de sphaera
# 1     Magnae pietatis et eruditionis viro D. Antonio...
# 2                                                &nbsp;
# 3                                  Tractatus de sphaera
# 4     Divae iustinae eximiae pietatis monachis, bona...
# ...                                                 ...
# 2724                    Liber de aggregatione stellarum
# 2725  On Climate Zones by Nunes and translated into ...
# 2726                                Mαθηματική σύνταξις
# 2727   Ioannis de Sacro Bosco proemium in suam Sphaeram
# 2728  Ioannis de Sacro Bosco Prooemium in suam sphaeram
#
#                      period  \
# 0          Late Middle Ages
# 1     Early Modern Period-2
# 2     Early Modern Period-2
# 3          Late Middle Ages
# 4     Early Modern Period-2
# ...                     ...
# 2724      Early Middle Ages
# 2725  Early Modern Period-2
# 2726              Antiquity
# 2727  Early Modern Period-2
# 2728  Early Modern Period-2
#
#                                        part_type_labels      dataset_labels  \
# 0                                Original Part, Content  Sphaera Sacrobosco
# 1           Original Part, Paratext – Dedication Letter  Sphaera Sacrobosco
# 2                                    Annotated, Content  Sphaera Sacrobosco
# 3                                Original Part, Content  Sphaera Sacrobosco
# 4     Original Part, Paratext – Letter to the reader...  Sphaera Sacrobosco
# ...                                                 ...                 ...
# 2724                               Translation, Content  Sphaera Sacrobosco
# 2725                               Translation, Content  Sphaera Sacrobosco
# 2726                             Original Part, Content  Sphaera Sacrobosco
# 2727                                 Annotated, Content  Sphaera Sacrobosco
# 2728                                 Annotated, Content  Sphaera Sacrobosco
#
#      corpora_labels     part_type  year       place
# 0      S. Tractatus           100  1550  Wittenberg
# 1      S. Tractatus         other  1550  Wittenberg
# 2      S. Tractatus  adaption_100  1550  Wittenberg
# 3      S. Tractatus           100  1561       Padua
# 4      S. Tractatus         other  1561       Padua
# ...             ...           ...   ...         ...
# 2724   S. Tractatus         other  1582     Antwerp
# 2725   S. Tractatus         other  1582     Antwerp
# 2726   S. Tractatus         other  1582     Antwerp
# 2727   S. Tractatus  adaption_100  1582     Antwerp
# 2728   S. Tractatus  adaption_100  1582     Antwerp
#
# [2729 rows x 14 columns]

# %%
# Count the number of unique values in the column
unique_count = df['bid'].nunique()

# Print the count of unique values
print(f'The number of unique values: {unique_count}')
# Out:
# The number of unique values: 359

# %%
# Define bins and labels
bins = [1470, 1490, 1510, 1530, 1550, 1570, 1590, 1610, 1630, 1650]
labels = ['1470-1489', '1490-1509', '1510-1529', '1530-1549', '1550-1569', '1570-1589', '1590-1609', '1610-1629', '1630-1649']

# Create a new column 'year_interval' to hold the 20-year intervals
df['year_interval'] = pd.cut(df['year'], bins=bins, labels=labels, right=False)

# Group by year_interval and part_type, and count unique book values (bids)
grouped = df.groupby(['year_interval', 'part_type'], observed=True)['bid'].nunique().reset_index(name='unique_books')

# Pivot table to prepare for plotting
pivot_df = grouped.pivot(index='year_interval', columns='part_type', values='unique_books').fillna(0)

# Verify the pivot DataFrame
print(pivot_df)

# Plotting
plt.figure(figsize=(12, 8))
for part_type in pivot_df.columns:
    plt.plot(pivot_df.index, pivot_df[part_type], marker='o', label=f'Part Type {part_type}')

plt.title('Number of Unique Books per Part Type Over 20-Year Intervals')
plt.xlabel('Year Interval')
plt.ylabel('Number of Unique Books')
plt.xticks(rotation=45)
plt.legend(title='Part Type')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# part_type       100  104  adaption_100  adaption_104  influenced_100  other
# year_interval
# 1470-1489      14.0  3.0           1.0           0.0             0.0    7.0
# 1490-1509      37.0  6.0          29.0           2.0             0.0   29.0
# 1510-1529      30.0  6.0          26.0           3.0             1.0   27.0
# 1530-1549      48.0  2.0          29.0           2.0             8.0   48.0
# 1550-1569      88.0  1.0          48.0           1.0            48.0   88.0
# 1570-1589      69.0  2.0          30.0           2.0            44.0   69.0
# 1590-1609      45.0  0.0          24.0           0.0            25.0   45.0
# 1610-1629      23.0  0.0          13.0           0.0            13.0   23.0
# 1630-1649       4.0  0.0           2.0           0.0             1.0    4.0

# %%
# Filter the DataFrame for part_type 104
filtered_df = df[df['part_type'] == 104  ]

# %%
filtered_df
# Out:
# Empty DataFrame
# Columns: [book, book_label, bid, custom_identifier, label, subject, title, period, part_type_labels, dataset_labels, corpora_labels, part_type, year, place, year_interval]
# Index: []

# %%
# Print unique values in the 'part_type' column
unique_part_types = df['part_type'].unique()

print(unique_part_types)
# Out:
# ['100' 'other' 'adaption_100' 'influenced_100' '104' 'adaption_104']

# %%
filtered_df = df[df['part_type'] == '104']

# %%
filtered_df
# Out:
#                                                    book  \
# 18    http://sphaera.mpiwg-berlin.mpg.de/id/item/b8e...
# 48    http://sphaera.mpiwg-berlin.mpg.de/id/item/776...
# 63    http://sphaera.mpiwg-berlin.mpg.de/id/item/814...
# 720   http://sphaera.mpiwg-berlin.mpg.de/id/item/798...
# 750   http://sphaera.mpiwg-berlin.mpg.de/id/item/f55...
# 1277  http://sphaera.mpiwg-berlin.mpg.de/id/item/b96...
# 1328  http://sphaera.mpiwg-berlin.mpg.de/id/item/6c8...
# 1353  http://sphaera.mpiwg-berlin.mpg.de/id/item/744...
# 1356  http://sphaera.mpiwg-berlin.mpg.de/id/item/0be...
# 1361  http://sphaera.mpiwg-berlin.mpg.de/id/item/91f...
# 1365  http://sphaera.mpiwg-berlin.mpg.de/id/item/b49...
# 1370  http://sphaera.mpiwg-berlin.mpg.de/id/item/5cc...
# 1373  http://sphaera.mpiwg-berlin.mpg.de/id/item/13e...
# 1400  http://sphaera.mpiwg-berlin.mpg.de/id/item/ce7...
# 1456  http://sphaera.mpiwg-berlin.mpg.de/id/item/608...
# 1486  http://sphaera.mpiwg-berlin.mpg.de/id/item/d48...
# 2003  http://sphaera.mpiwg-berlin.mpg.de/id/item/ceb...
# 2273  http://sphaera.mpiwg-berlin.mpg.de/id/item/114...
# 2346  http://sphaera.mpiwg-berlin.mpg.de/id/item/9b9...
# 2552  http://sphaera.mpiwg-berlin.mpg.de/id/item/75a...
#
#                                              book_label   bid  \
# 18             Commentum super tractatum sphaerae mundi  1622
# 48                                        Spherae Mundi  1650
# 63      Sphera cum commentis in hoc volumine contentis.  1659
# 720             Nota eorum quæ in hoc libro continentur  1823
# 750                                        Sphera Mundi  1826
# 1277                                  Tratado da sphera  1910
# 1328  Opusculum de Sphaera clarissimi philosophi Ioa...  1918
# 1353                            Novicijs adolescentibus  1923
# 1356        Spaerae Mundi Compendium foeliciter inchoat  1924
# 1361       Sphaerae mundi compendium foeliciter inchoat  1925
# 1365                                      Sphaera mundi  1926
# 1370                            Noviciis adolescentibus  1928
# 1373                                       Sphera mundi  1929
# 1400                                      Sphaera mundi  1930
# 1456           Spherae tractatus Ioannis de Sacro Busto  1941
# 1486                                      Spherae Mundi  1942
# 2003  Silvestri de Prierio in spheram ac Theoricas p...  2092
# 2273                               Speculum astrologiae  2190
# 2346                      Sphaera Ioannis de Sacrobusto  2219
# 2552                               Speculum astrologiae  2258
#
#      custom_identifier                                   label  \
# 18                 104  Theoricae novae planetarum of Peurbach
# 48                 104  Theoricae novae planetarum of Peurbach
# 63                 104  Theoricae novae planetarum of Peurbach
# 720                104  Theoricae novae planetarum of Peurbach
# 750                104  Theoricae novae planetarum of Peurbach
# 1277               104  Theoricae novae planetarum of Peurbach
# 1328               104  Theoricae novae planetarum of Peurbach
# 1353               104  Theoricae novae planetarum of Peurbach
# 1356               104  Theoricae novae planetarum of Peurbach
# 1361               104  Theoricae novae planetarum of Peurbach
# 1365               104  Theoricae novae planetarum of Peurbach
# 1370               104  Theoricae novae planetarum of Peurbach
# 1373               104  Theoricae novae planetarum of Peurbach
# 1400               104  Theoricae novae planetarum of Peurbach
# 1456               104  Theoricae novae planetarum of Peurbach
# 1486               104  Theoricae novae planetarum of Peurbach
# 2003               104  Theoricae novae planetarum of Peurbach
# 2273               104  Theoricae novae planetarum of Peurbach
# 2346               104  Theoricae novae planetarum of Peurbach
# 2552               104  Theoricae novae planetarum of Peurbach
#
#                                                 subject  \
# 18    http://sphaera.mpiwg-berlin.mpg.de/id/part/1ea...
# 48    http://sphaera.mpiwg-berlin.mpg.de/id/part/1ea...
# 63    http://sphaera.mpiwg-berlin.mpg.de/id/part/1ea...
# 720   http://sphaera.mpiwg-berlin.mpg.de/id/part/1ea...
# 750   http://sphaera.mpiwg-berlin.mpg.de/id/part/1ea...
# 1277  http://sphaera.mpiwg-berlin.mpg.de/id/part/1ea...
# 1328  http://sphaera.mpiwg-berlin.mpg.de/id/part/1ea...
# 1353  http://sphaera.mpiwg-berlin.mpg.de/id/part/1ea...
# 1356  http://sphaera.mpiwg-berlin.mpg.de/id/part/1ea...
# 1361  http://sphaera.mpiwg-berlin.mpg.de/id/part/1ea...
# 1365  http://sphaera.mpiwg-berlin.mpg.de/id/part/1ea...
# 1370  http://sphaera.mpiwg-berlin.mpg.de/id/part/1ea...
# 1373  http://sphaera.mpiwg-berlin.mpg.de/id/part/1ea...
# 1400  http://sphaera.mpiwg-berlin.mpg.de/id/part/1ea...
# 1456  http://sphaera.mpiwg-berlin.mpg.de/id/part/1ea...
# 1486  http://sphaera.mpiwg-berlin.mpg.de/id/part/1ea...
# 2003  http://sphaera.mpiwg-berlin.mpg.de/id/part/1ea...
# 2273  http://sphaera.mpiwg-berlin.mpg.de/id/part/1ea...
# 2346  http://sphaera.mpiwg-berlin.mpg.de/id/part/1ea...
# 2552  http://sphaera.mpiwg-berlin.mpg.de/id/part/1ea...
#
#                                                   title  \
# 18    Theoricae novae planetarum Georgii Purbachii a...
# 48    Theoricae novae planetarum Georgii Purbachii a...
# 63    Theoricae novae planetarum Georgii Purbachii a...
# 720   Theoricae novae planetarum Georgii Purbachii a...
# 750   Theoricae novae planetarum Georgii Purbachii a...
# 1277  Theoricae novae planetarum Georgii Purbachii a...
# 1328  Theoricae novae planetarum Georgii Purbachii a...
# 1353  Theoricae novae planetarum Georgii Purbachii a...
# 1356  Theoricae novae planetarum Georgii Purbachii a...
# 1361  Theoricae novae planetarum Georgii Purbachii a...
# 1365  Theoricae novae planetarum Georgii Purbachii a...
# 1370  Theoricae novae planetarum Georgii Purbachii a...
# 1373  Theoricae novae planetarum Georgii Purbachii a...
# 1400  Theoricae novae planetarum Georgii Purbachii a...
# 1456  Theoricae novae planetarum Georgii Purbachii a...
# 1486  Theoricae novae planetarum Georgii Purbachii a...
# 2003  Theoricae novae planetarum Georgii Purbachii a...
# 2273  Theoricae novae planetarum Georgii Purbachii a...
# 2346  Theoricae novae planetarum Georgii Purbachii a...
# 2552  Theoricae novae planetarum Georgii Purbachii a...
#
#                      period        part_type_labels  \
# 18    Early Modern Period-1  Original Part, Content
# 48    Early Modern Period-1  Original Part, Content
# 63    Early Modern Period-1  Original Part, Content
# 720   Early Modern Period-1  Original Part, Content
# 750   Early Modern Period-1  Original Part, Content
# 1277  Early Modern Period-1  Original Part, Content
# 1328  Early Modern Period-1  Original Part, Content
# 1353  Early Modern Period-1  Original Part, Content
# 1356  Early Modern Period-1  Original Part, Content
# 1361  Early Modern Period-1  Original Part, Content
# 1365  Early Modern Period-1  Original Part, Content
# 1370  Early Modern Period-1  Original Part, Content
# 1373  Early Modern Period-1  Original Part, Content
# 1400  Early Modern Period-1  Original Part, Content
# 1456  Early Modern Period-1  Original Part, Content
# 1486  Early Modern Period-1  Original Part, Content
# 2003  Early Modern Period-1  Original Part, Content
# 2273  Early Modern Period-1  Original Part, Content
# 2346  Early Modern Period-1  Original Part, Content
# 2552  Early Modern Period-1  Original Part, Content
#
#                                          dataset_labels  \
# 18               Sphaera Sacrobosco, Theoricae Peurbach
# 48               Sphaera Sacrobosco, Theoricae Peurbach
# 63    Theoricae Peurbach, Theoricae Gerard, Sphaera ...
# 720              Theoricae Peurbach, Sphaera Sacrobosco
# 750              Sphaera Sacrobosco, Theoricae Peurbach
# 1277             Sphaera Sacrobosco, Theoricae Peurbach
# 1328                                 Sphaera Sacrobosco
# 1353             Sphaera Sacrobosco, Theoricae Peurbach
# 1356             Sphaera Sacrobosco, Theoricae Peurbach
# 1361             Sphaera Sacrobosco, Theoricae Peurbach
# 1365             Sphaera Sacrobosco, Theoricae Peurbach
# 1370             Sphaera Sacrobosco, Theoricae Peurbach
# 1373  Sphaera Sacrobosco, Theoricae Peurbach, Theori...
# 1400             Sphaera Sacrobosco, Theoricae Peurbach
# 1456  Sphaera Sacrobosco, Theoricae Peurbach, Theori...
# 1486             Sphaera Sacrobosco, Theoricae Peurbach
# 2003             Sphaera Sacrobosco, Theoricae Peurbach
# 2273             Sphaera Sacrobosco, Theoricae Peurbach
# 2346                                 Sphaera Sacrobosco
# 2552             Sphaera Sacrobosco, Theoricae Peurbach
#
#                 corpora_labels part_type  year   place year_interval
# 18    S. Tractatus & Theoricae       104  1494  Venice     1490-1509
# 48    S. Tractatus & Theoricae       104  1513  Venice     1510-1529
# 63    S. Tractatus & Theoricae       104  1518  Venice     1510-1529
# 720   S. Tractatus & Theoricae       104  1508  Venice     1490-1509
# 750   S. Tractatus & Theoricae       104  1499  Venice     1490-1509
# 1277  S. Tractatus & Theoricae       104  1537  Lisbon     1530-1549
# 1328  S. Tractatus & Theoricae       104  1518  Vienna     1510-1529
# 1353  S. Tractatus & Theoricae       104  1482  Venice     1470-1489
# 1356  S. Tractatus & Theoricae       104  1488  Venice     1470-1489
# 1361  S. Tractatus & Theoricae       104  1490  Venice     1490-1509
# 1365  S. Tractatus & Theoricae       104  1491  Venice     1490-1509
# 1370  S. Tractatus & Theoricae       104  1485  Venice     1470-1489
# 1373  S. Tractatus & Theoricae       104  1518  Venice     1510-1529
# 1400  S. Tractatus & Theoricae       104  1501  Venice     1490-1509
# 1456  S. Tractatus & Theoricae       104  1531  Venice     1530-1549
# 1486  S. Tractatus & Theoricae       104  1519  Venice     1510-1529
# 2003  S. Tractatus & Theoricae       104  1514   Milan     1510-1529
# 2273  S. Tractatus & Theoricae       104  1583    Lyon     1570-1589
# 2346  S. Tractatus & Theoricae       104  1552  Venice     1550-1569
# 2552  S. Tractatus & Theoricae       104  1581    Lyon     1570-1589

# %%
# Count the number of unique values in the column
unique_count = filtered_df['bid'].nunique()

# Print the count of unique values
print(f'The number of unique values: {unique_count}')
# Out:
# The number of unique values: 20

# %%
# Define bins and labels
bins = [1470, 1490, 1510, 1530, 1550, 1570, 1590, 1610, 1630, 1650]
labels = ['1470-1489', '1490-1509', '1510-1529', '1530-1549', '1550-1569', '1570-1589', '1590-1609', '1610-1629', '1630-1649']

# Create a new column 'year_interval' to hold the 20-year intervals
df['year_interval'] = pd.cut(df['year'], bins=bins, labels=labels, right=False)

# Group by year_interval and part_type, and count unique book values (bids)
grouped = df.groupby(['year_interval', 'part_type'], observed=True)['bid'].nunique().reset_index(name='unique_books')

# Calculate total unique books for each interval
total_unique_books = df.groupby('year_interval')['bid'].nunique().reset_index(name='unique_books')
total_unique_books['part_type'] = 'Total'

# Combine the data
combined = pd.concat([grouped, total_unique_books])

# Pivot table to prepare for plotting
pivot_df = combined.pivot(index='year_interval', columns='part_type', values='unique_books').fillna(0)

# Verify the pivot DataFrame
print(pivot_df)

# Plotting
plt.figure(figsize=(12, 8))
for part_type in pivot_df.columns:
    plt.plot(pivot_df.index, pivot_df[part_type], marker='o', label=f'Part Type {part_type}')

plt.title('Number of Unique Books per Part Type Over 20-Year Intervals')
plt.xlabel('Year Interval')
plt.ylabel('Number of Unique Books')
plt.xticks(rotation=45)
plt.legend(title='Part Type')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\nogas\AppData\Local\Temp\ipykernel_22864\1938833126.py:12: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   total_unique_books = df.groupby('year_interval')['bid'].nunique().reset_index(name='unique_books')
# part_type       100  104  Total  adaption_100  adaption_104  influenced_100  \
# year_interval
# 1470-1489      14.0  3.0   14.0           1.0           0.0             0.0
# 1490-1509      37.0  6.0   37.0          29.0           2.0             0.0
# 1510-1529      30.0  6.0   30.0          26.0           3.0             1.0
# 1530-1549      48.0  2.0   48.0          29.0           2.0             8.0
# 1550-1569      88.0  1.0   88.0          48.0           1.0            48.0
# 1570-1589      69.0  2.0   69.0          30.0           2.0            44.0
# 1590-1609      45.0  0.0   45.0          24.0           0.0            25.0
# 1610-1629      23.0  0.0   23.0          13.0           0.0            13.0
# 1630-1649       4.0  0.0    4.0           2.0           0.0             1.0
#
# part_type      other
# year_interval
# 1470-1489        7.0
# 1490-1509       29.0
# 1510-1529       27.0
# 1530-1549       48.0
# 1550-1569       88.0
# 1570-1589       69.0
# 1590-1609       45.0
# 1610-1629       23.0
# 1630-1649        4.0

# %%
# Define bins and labels
bins = [1470, 1490, 1510, 1530, 1550, 1570, 1590, 1610, 1630, 1650]
labels = ['1470-1489', '1490-1509', '1510-1529', '1530-1549', '1550-1569', '1570-1589', '1590-1609', '1610-1629', '1630-1649']

# Create a new column 'year_interval' to hold the 20-year intervals
df['year_interval'] = pd.cut(df['year'], bins=bins, labels=labels, right=False)

# Group by year_interval and part_type, and count unique book values (bids)
grouped = df.groupby(['year_interval', 'part_type'], observed=True)['bid'].nunique().reset_index(name='unique_books')

# Filter out part_type 'other'
grouped = grouped[grouped['part_type'] != 'other']

# Calculate total unique books for each interval
total_unique_books = df.groupby('year_interval')['bid'].nunique().reset_index(name='unique_books')
total_unique_books['part_type'] = 'Total'

# Combine the data
combined = pd.concat([grouped, total_unique_books])

# Pivot table to prepare for plotting
pivot_df = combined.pivot(index='year_interval', columns='part_type', values='unique_books').fillna(0)

# Verify the pivot DataFrame
print(pivot_df)

# Plotting
plt.figure(figsize=(12, 8))
for part_type in pivot_df.columns:
    plt.plot(pivot_df.index, pivot_df[part_type], marker='o', label=f'Part Type {part_type}')

plt.title('Number of Unique Books per Part Type Over 20-Year Intervals')
plt.xlabel('Year Interval')
plt.ylabel('Number of Unique Books')
plt.xticks(rotation=45)
plt.legend(title='Part Type')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\nogas\AppData\Local\Temp\ipykernel_22864\3318225806.py:15: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   total_unique_books = df.groupby('year_interval')['bid'].nunique().reset_index(name='unique_books')
# part_type       100  104  Total  adaption_100  adaption_104  influenced_100
# year_interval
# 1470-1489      14.0  3.0   14.0           1.0           0.0             0.0
# 1490-1509      37.0  6.0   37.0          29.0           2.0             0.0
# 1510-1529      30.0  6.0   30.0          26.0           3.0             1.0
# 1530-1549      48.0  2.0   48.0          29.0           2.0             8.0
# 1550-1569      88.0  1.0   88.0          48.0           1.0            48.0
# 1570-1589      69.0  2.0   69.0          30.0           2.0            44.0
# 1590-1609      45.0  0.0   45.0          24.0           0.0            25.0
# 1610-1629      23.0  0.0   23.0          13.0           0.0            13.0
# 1630-1649       4.0  0.0    4.0           2.0           0.0             1.0
