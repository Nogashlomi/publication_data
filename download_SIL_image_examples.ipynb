# %%
import practicalSPARQL
import pandas as pd
import requests
import os

# %%
root_q = 'queries'
root_d = 'results'

# read login data
login = pd.read_json('config_sparql.json')
ENDPOINT = login['endpoint'][0]
USERNAME = login['username'][0]
PASSWORD = login['password'][0]

# create sparql object
sparql = practicalSPARQL.practicalWrapper(ENDPOINT)
sparql.setCredentials(USERNAME, PASSWORD)

print("--- Querying ENDPOINT: {} ---".format(ENDPOINT))
# Out:
# --- Querying ENDPOINT: http://devmeta.sphaera.mpiwg-berlin.mpg.de/sparql ---

# %%
q = practicalSPARQL.stringify_SPARQL('elements_query_w_iiif_230724.sparql')    # select data from the ttl file as a dataframe
df = sparql.select_as_dataframe(q) 
len(df)
# Out:
# 21116

# %%
df = df.drop_duplicates(subset=['cluster_name'], keep='first')
df
# Out:
#                                                   images   cluster_name  \
# 0      http://dev.sphaera.mpiwg-berlin.mpg.de/contain...  SAC_SIL_01420
# 1      http://dev.sphaera.mpiwg-berlin.mpg.de/contain...  SAC_SIL_01528
# 2      http://dev.sphaera.mpiwg-berlin.mpg.de/contain...  SAC_SIL_03692
# 3      http://dev.sphaera.mpiwg-berlin.mpg.de/contain...  SAC_SIL_00261
# 4      http://dev.sphaera.mpiwg-berlin.mpg.de/contain...  SAC_SIL_00477
# ...                                                  ...            ...
# 20990  http://dev.sphaera.mpiwg-berlin.mpg.de/contain...  SAC_SIL_03460
# 20991  http://dev.sphaera.mpiwg-berlin.mpg.de/contain...  SAC_SIL_03495
# 21083  http://dev.sphaera.mpiwg-berlin.mpg.de/contain...  SAC_SIL_01903
# 21085  http://dev.sphaera.mpiwg-berlin.mpg.de/contain...  SAC_SIL_03198
# 21114  http://dev.sphaera.mpiwg-berlin.mpg.de/contain...  SAC_SIL_03224
#
#                                            cks  \
# 0      CK_Right and Oblique Sphere, CK_Horizon
# 1      CK_Horizon, CK_Right and Oblique Sphere
# 2      CK_Horizon, CK_Right and Oblique Sphere
# 3                             CK_Lunar Eclipse
# 4                              CK_Lunar Phases
# ...                                        ...
# 20990     CK_Superior Planets Lines and Motion
# 20991     CK_Superior Planets Lines and Motion
# 21083                   CK_Centrality of Earth
# 21085              CK_Right and Oblique Sphere
# 21114   CK_Circles of Equant Deferent Epicycle
#
#                                                     book   bid  \
# 0      http://sphaera.mpiwg-berlin.mpg.de/id/item/21e...  1902
# 1      http://sphaera.mpiwg-berlin.mpg.de/id/item/21e...  1902
# 2      http://sphaera.mpiwg-berlin.mpg.de/id/item/21e...  1902
# 3      http://sphaera.mpiwg-berlin.mpg.de/id/item/21e...  1902
# 4      http://sphaera.mpiwg-berlin.mpg.de/id/item/21e...  1902
# ...                                                  ...   ...
# 20990  http://sphaera.mpiwg-berlin.mpg.de/id/item/75a...  2258
# 20991  http://sphaera.mpiwg-berlin.mpg.de/id/item/75a...  2258
# 21083  http://sphaera.mpiwg-berlin.mpg.de/id/item/395...  2263
# 21085  http://sphaera.mpiwg-berlin.mpg.de/id/item/395...  2263
# 21114  http://sphaera.mpiwg-berlin.mpg.de/id/item/c9c...  2267
#
#                                         part_or_adaption  \
# 0      http://sphaera.mpiwg-berlin.mpg.de/id/part/47c...
# 1      http://sphaera.mpiwg-berlin.mpg.de/id/part/47c...
# 2      http://sphaera.mpiwg-berlin.mpg.de/id/part/47c...
# 3      http://sphaera.mpiwg-berlin.mpg.de/id/part/47c...
# 4      http://sphaera.mpiwg-berlin.mpg.de/id/part/47c...
# ...                                                  ...
# 20990  http://sphaera.mpiwg-berlin.mpg.de/id/adaption...
# 20991  http://sphaera.mpiwg-berlin.mpg.de/id/adaption...
# 21083  http://sphaera.mpiwg-berlin.mpg.de/id/part/078...
# 21085  http://sphaera.mpiwg-berlin.mpg.de/id/part/078...
# 21114  http://sphaera.mpiwg-berlin.mpg.de/id/part/ced...
#
#                     part_or_adaption_label custom_identifier        place  \
# 0               Compendium by P. Valeriano               251        Paris
# 1               Compendium by P. Valeriano               251        Paris
# 2               Compendium by P. Valeriano               251        Paris
# 3               Compendium by P. Valeriano               251        Paris
# 4               Compendium by P. Valeriano               251        Paris
# ...                                    ...               ...          ...
# 20990  Commentary on Theorica by Peuerbach               349         Lyon
# 20991  Commentary on Theorica by Peuerbach               349         Lyon
# 21083     Strigel's treatise on the Sphere               779   Wittenberg
# 21085     Strigel's treatise on the Sphere               779   Wittenberg
# 21114                  Sphere by Maurolico               808  Mexico City
#
#        year                       bb pagenum  \
# 0      1552    xywh=720,1179,492,485      85
# 1      1552    xywh=1595,477,525,502      85
# 2      1552     xywh=667,651,538,492      85
# 3      1552    xywh=1280,523,892,888      99
# 4      1552    xywh=477,153,702,1269      99
# ...     ...                      ...     ...
# 20990  1581     xywh=273,596,129,132      86
# 20991  1581      xywh=67,477,213,206      86
# 21083  1565  xywh=196,1770,1068,1148      46
# 21085  1565   xywh=380,1119,1560,763      31
# 21114  1578      xywh=264,184,81,166      46
#
#                                                IIIFimage
# 0      http://db.sphaera.mpiwg-berlin.mpg.de/Scaler/I...
# 1      http://db.sphaera.mpiwg-berlin.mpg.de/Scaler/I...
# 2      http://db.sphaera.mpiwg-berlin.mpg.de/Scaler/I...
# 3      http://db.sphaera.mpiwg-berlin.mpg.de/Scaler/I...
# 4      http://db.sphaera.mpiwg-berlin.mpg.de/Scaler/I...
# ...                                                  ...
# 20990  http://db.sphaera.mpiwg-berlin.mpg.de/Scaler/I...
# 20991  http://db.sphaera.mpiwg-berlin.mpg.de/Scaler/I...
# 21083  http://db.sphaera.mpiwg-berlin.mpg.de/Scaler/I...
# 21085  http://db.sphaera.mpiwg-berlin.mpg.de/Scaler/I...
# 21114  http://db.sphaera.mpiwg-berlin.mpg.de/Scaler/I...
#
# [3565 rows x 13 columns]

# %%
#download images

for entry in df.iterrows():
    downloadlink = entry[1].IIIFimage
    downloadlink = downloadlink.split("full")
    downloadlink_merged = downloadlink[0] + (entry[1].bb).split("=")[1] + "/!300,300" + downloadlink[1] 
    img_data = requests.get(downloadlink_merged).content
    cks = entry[1].cks.split(", ")
    for ck in cks:
        if not os.path.exists("images_ck/" + ck + "/"):
            os.makedirs("images_ck/" + ck + "/")
        with open("images_ck/" + ck + "/"+ entry[1].cluster_name +".jpg", 'wb') as handler:
            handler.write(img_data)
