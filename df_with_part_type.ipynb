# %%
import practicalSPARQL
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import practicalSPARQL
import numpy as np
from collections import Counter

# %%
root_q = 'queries'
root_d = 'results'

# read login data
login = pd.read_json('sparql_config/config_sparql.json')
ENDPOINT = login['endpoint'][0]
USERNAME = login['username'][0]
PASSWORD = login['password'][0]

# create sparql object
sparql = practicalSPARQL.practicalWrapper(ENDPOINT)
sparql.setCredentials(USERNAME, PASSWORD)

print("--- Querying ENDPOINT: {} ---".format(ENDPOINT))
# Out:
# --- Querying ENDPOINT: http://devmeta.sphaera.mpiwg-berlin.mpg.de/sparql ---

# %%
q = practicalSPARQL.stringify_SPARQL('sparql_config/textparts_and_books_250724.sparql')
books_text_parts = sparql.select_as_dataframe(q) 
books_text_parts

# %%
path_to_csv = '/Users/nogashlomi/projects/Image_data/dissertation/full_image_data_feb_25.csv'
df = pd.read_csv(path_to_csv)

# %%
#all adaption of 100

q = practicalSPARQL.stringify_SPARQL('sparql_config/adaptions_100.sparql')
df_adaptions_100 = sparql.select_as_dataframe(q)

# %%
#all influenced by 100

q = practicalSPARQL.stringify_SPARQL('sparql_config/influenced_100.sparql')
df_influenced_100 = sparql.select_as_dataframe(q)

# %%
#all adaption of 104

q = practicalSPARQL.stringify_SPARQL('sparql_config/adaptions_104.sparql')
df_adaptions_104 = sparql.select_as_dataframe(q)

# %%
#all influenced by 104

q = practicalSPARQL.stringify_SPARQL('sparql_config/Influenced_104.sparql')
df_influenced_104 = sparql.select_as_dataframe(q)

# %%
# adding a part-type column to df 

#Define the value to check for part-type: 100
specific_value_100 = "http://sphaera.mpiwg-berlin.mpg.de/id/part/c6145ca3-317c-4724-a344-3c2e106fe26b"

specific_value_104 = "http://sphaera.mpiwg-berlin.mpg.de/id/part/1eaef0cc-5d5d-45fb-a33c-0fe5b62add79"

# Convert the columns to sets for faster lookup
adaptions_set_100 = set(df_adaptions_100['adaption'])
influenced_set_100 = set(df_influenced_100['influenced_part'])
adaptions_set_104 = set(df_adaptions_104['adaption'])
influenced_set_104 = set(df_influenced_104['influenced_part'])

# Define the function to determine the part type
def determine_part_type(part_or_adaption):
    if part_or_adaption == specific_value_100:
        return '100'
    elif part_or_adaption in adaptions_set_100:
        return 'adaption_100'
    elif part_or_adaption in influenced_set_100:
        return 'influenced_100'
    if part_or_adaption == specific_value_104:
        return '104'
    elif part_or_adaption in adaptions_set_104:
        return 'adaption_104'
    elif part_or_adaption in influenced_set_104:
        return 'influenced_104'
    else:
        return 'other'

# Apply the function to the 'part_or_adaption' column
df['part_type'] = df['part_or_adaption'].apply(determine_part_type)

# %%
df
# Out:
#        Unnamed: 0                                             images  \
# 0               0  http://devmeta.sphaera.mpiwg-berlin.mpg.de/res...
# 1               1  http://devmeta.sphaera.mpiwg-berlin.mpg.de/res...
# 2               2  http://devmeta.sphaera.mpiwg-berlin.mpg.de/res...
# 3               3  http://devmeta.sphaera.mpiwg-berlin.mpg.de/res...
# 4               4  http://devmeta.sphaera.mpiwg-berlin.mpg.de/res...
# ...           ...                                                ...
# 21176       21176  http://devmeta.sphaera.mpiwg-berlin.mpg.de/res...
# 21177       21177  http://devmeta.sphaera.mpiwg-berlin.mpg.de/res...
# 21178       21178  http://devmeta.sphaera.mpiwg-berlin.mpg.de/res...
# 21179       21179  http://devmeta.sphaera.mpiwg-berlin.mpg.de/res...
# 21180       21180  http://devmeta.sphaera.mpiwg-berlin.mpg.de/res...
#
#                                                 keywords cluster_name  \
# 0      CK_Relations Between the Spheres of the Sun an...    SIL_03326
# 1      MVK_Pictorial_Diagrams;CK_08 Spheres;CK_Terraq...    SIL_02440
# 2      CK_Sphericity of the Heavens;MVK_Pictorial_Dia...    SIL_03167
# 3      MVK_Pictorial_Illustrations;MTK_Sphericity of ...    SIL_03188
# 4      SK_2.8 Extended Uses of Sign;CK_Pyramid of a S...    SIL_00191
# ...                                                  ...          ...
# 21176  MVK_Pictorial_Diagrams;SK_4.4 Cause of lunar e...    SIL_00267
# 21177  CK_Solar Eclipse;MVK_Pictorial_Diagrams;MTK_So...    SIL_03580
# 21178  CK_Lunar Eclipse;MVK_Pictorial_Diagrams;MTK_Lu...    SIL_03550
# 21179  CK_Lunar Phases;MVK_Pictorial_Diagrams;MTK_Lun...    SIL_03543
# 21180  MVK_Pictorial_Illustrations;SK_4.4 Cause of lu...    SIL_00261
#
#                                                  authors  \
# 0                Sacrobosco, Johannes de;Beyer, Hartmann
# 1                                         Catena, Pietro
# 2                                         Catena, Pietro
# 3                                         Catena, Pietro
# 4                                         Catena, Pietro
# ...                                                  ...
# 21176  Sacrobosco, Johannes de;Vinet, Élie;Hero, Albe...
# 21177  Sacrobosco, Johannes de;Vinet, Élie;Hero, Albe...
# 21178  Sacrobosco, Johannes de;Vinet, Élie;Hero, Albe...
# 21179  Sacrobosco, Johannes de;Vinet, Élie;Hero, Albe...
# 21180  Vinet, Élie;Sacrobosco, Johannes de;Hero, Albe...
#
#                             publishers                         printers  \
# 0      Company Heirs of Peter I. Seitz  Company Heirs of Peter I. Seitz
# 1                  Percacino, Grazioso              Percacino, Grazioso
# 2                  Percacino, Grazioso              Percacino, Grazioso
# 3                  Percacino, Grazioso              Percacino, Grazioso
# 4                  Percacino, Grazioso              Percacino, Grazioso
# ...                                ...                              ...
# 21176                    Bellère, Jean                    Bellère, Jean
# 21177                    Bellère, Jean                    Bellère, Jean
# 21178                    Bellère, Jean                    Bellère, Jean
# 21179                    Bellère, Jean                    Bellère, Jean
# 21180                    Bellère, Jean                    Bellère, Jean
#
#             place  year   bid  \
# 0      Wittenberg  1550  1594
# 1           Padua  1561  1597
# 2           Padua  1561  1597
# 3           Padua  1561  1597
# 4           Padua  1561  1597
# ...           ...   ...   ...
# 21176     Antwerp  1582  2281
# 21177     Antwerp  1582  2281
# 21178     Antwerp  1582  2281
# 21179     Antwerp  1582  2281
# 21180     Antwerp  1582  2281
#
#                                                     book  \
# 0      http://sphaera.mpiwg-berlin.mpg.de/id/item/8f5...
# 1      http://sphaera.mpiwg-berlin.mpg.de/id/item/ba1...
# 2      http://sphaera.mpiwg-berlin.mpg.de/id/item/ba1...
# 3      http://sphaera.mpiwg-berlin.mpg.de/id/item/ba1...
# 4      http://sphaera.mpiwg-berlin.mpg.de/id/item/ba1...
# ...                                                  ...
# 21176  http://sphaera.mpiwg-berlin.mpg.de/id/item/af4...
# 21177  http://sphaera.mpiwg-berlin.mpg.de/id/item/af4...
# 21178  http://sphaera.mpiwg-berlin.mpg.de/id/item/af4...
# 21179  http://sphaera.mpiwg-berlin.mpg.de/id/item/af4...
# 21180  http://sphaera.mpiwg-berlin.mpg.de/id/item/af4...
#
#                                         part_or_adaption  \
# 0      http://sphaera.mpiwg-berlin.mpg.de/id/adaption...
# 1      http://sphaera.mpiwg-berlin.mpg.de/id/part/524...
# 2      http://sphaera.mpiwg-berlin.mpg.de/id/part/524...
# 3      http://sphaera.mpiwg-berlin.mpg.de/id/part/524...
# 4      http://sphaera.mpiwg-berlin.mpg.de/id/part/524...
# ...                                                  ...
# 21176  http://sphaera.mpiwg-berlin.mpg.de/id/part/47c...
# 21177  http://sphaera.mpiwg-berlin.mpg.de/id/part/47c...
# 21178  http://sphaera.mpiwg-berlin.mpg.de/id/part/47c...
# 21179  http://sphaera.mpiwg-berlin.mpg.de/id/part/47c...
# 21180  http://sphaera.mpiwg-berlin.mpg.de/id/part/47c...
#
#            part_or_adaption_label  pagenum                        bb  \
# 0            Tractatus de sphaera       27      xywh=116,929,875,476
# 1            Sphaera by P. Catena        5  xywh=1944,1029,1376,1404
# 2            Sphaera by P. Catena        7    xywh=2028,1340,638,601
# 3            Sphaera by P. Catena        9  xywh=1950,1422,1104,1234
# 4            Sphaera by P. Catena       16    xywh=2172,1190,362,561
# ...                           ...      ...                       ...
# 21176  Compendium by P. Valeriano      339      xywh=254,288,788,635
# 21177  Compendium by P. Valeriano      340    xywh=460,276,1026,1504
# 21178  Compendium by P. Valeriano      341    xywh=130,590,1067,1575
# 21179  Compendium by P. Valeriano      343     xywh=281,570,866,1617
# 21180  Compendium by P. Valeriano      344    xywh=435,930,1022,1034
#
#             part_type
# 0        adaption_100
# 1      influenced_100
# 2      influenced_100
# 3      influenced_100
# 4      influenced_100
# ...               ...
# 21176  influenced_100
# 21177  influenced_100
# 21178  influenced_100
# 21179  influenced_100
# 21180  influenced_100
#
# [21181 rows x 16 columns]

# %%
df.to_excel('all_elements_with_part_type.xlsx', index=False)

# %%
# Count the number of images per part type
image_count_per_part = df.groupby('part_type')['images'].count().reset_index()

# Rename the columns for clarity
image_count_per_part.columns = ['part_type', 'image_count']

# %%
image_count_per_part
# Out:
#         part_type  image_count
# 0             100         1261
# 1             104          313
# 2    adaption_100         9598
# 3    adaption_104          879
# 4  influenced_100         4469
# 5           other         4661

# %%
#get unique keywords that go with part 100 images

# Step 1: Filter the DataFrame
filtered_df = df[df['part_type'] == '100']

# Step 2 & 3: Extract the 'keywords' column and split by ";"
all_keywords = filtered_df['keywords'].str.split(';')

# Step 4: Flatten the list of lists
flattened_keywords = [keyword for sublist in all_keywords for keyword in sublist]

# Step 5: Get unique keywords
unique_keywords = set(flattened_keywords)

# %%
# Step 3: Categorize keywords from unique_keywords
sk_keywords = []
ck_keywords = []
other_keywords = []

for keyword in unique_keywords:
    if keyword.startswith('SK'):
        sk_keywords.append(keyword)
    elif keyword.startswith('CK'):
        ck_keywords.append(keyword)
    else:
        other_keywords.append(keyword)

# %%
# Step 4: Print results
print("SK Keywords:")
print(sk_keywords)
print(f"Count: {len(sk_keywords)}\n")

print("CK Keywords:")
print(ck_keywords)
print(f"Count: {len(ck_keywords)}\n")

print("Other Keywords:")
print(other_keywords)
print(f"Count: {len(other_keywords)}\n")
# Out:
# SK Keywords:
# ['SK_1.5 Their movements', 'SK_3.13 Between the Equator and Tropic of Cancer', 'SK_3.18 at the north pole', 'SK_3.16 At the arctic circle', 'SK_3.19 The Seven Climes', 'SK_3.14 At the Tropic of Cancer', 'SK_1.7 The Heavens Spherical', 'SK_Disputatio_Against Gerard', 'SK_2.8 Extended Uses of Sign', 'SK_2.5 The Zodiac', 'SK_4.4 Cause of lunar eclipse', 'SK_1.11 Surface of the sea spherical', 'SK_3.9 Movement of the Sun', 'SK_1.14 And a Mere Point in the universe', 'SK_3.8 Inequality of Days', 'SK_2.6 The Twelve Signs', 'SK_2.2 The Equinoctial', 'SK_3.15 Between the Tropic and the Arctic Circles', 'SK_2.14 Arctic and Antarctic Circles', 'SK_1.4 The Heavens', 'SK_Theodosius Spherics', 'SK_4.5 Cause of solar eclipse', 'SK_3.1 Rising and settings of the signs', 'SK_1.3 The Four Elements', 'SK_3.7 Oblique Ascensions', 'SK_4.2 Of the other planets: Equant, Deferent, and Epicycle', 'SK_1.9 The earth sphere', 'SK_2.17 The Five Zones', 'SK_1.6 Revolution of the heavens from east to west', 'SK_3.27 Beyond it', 'SK_3.6 Right Ascensions', 'SK_3.10 Day and Night', 'SK_3.12 Dwellers at the equator', 'SK_1.1 Sphere defined', 'SK_1.16 measuring the earth’s circumference ', 'SK_Geom Speculative', 'SK_3.17 Between the Arctic circle and the North Pole', 'SK_2.13 Tropics of Cancer and Capricorn', 'SK_1.2 Sphere Divided', 'SK_2.11 The Horizon', 'SK_2.9 Colures', 'SK_1.13 The earth central', 'SK_4.3 Stationary, direct, and retrograde', 'SK_2.7 The Ecliptic', 'SK_2.1 celestial circles', 'SK_3.5 Heliacal Rising and Setting', 'SK_2.4 The north and south poles', 'SK_2.12 Elevation of the Pole', 'SK_4.1 Movement of the sun']
# Count: 49
#
# CK Keywords:
# ['CK_Poles of the world', 'CK_Elevation of the Pole', 'CK_T-O Maps', 'CK_Armillary Sphere', 'CK_Geometry for Geometry', 'CK_Cosmic Rising and Setting', 'CK_Ascensions in the Right and Oblique Sphere', 'CK_Four Solstices', 'CK_Populated Earth', 'CK_Equinoctial', 'CK_Sphericity of the Heavens', 'CK_Lunar Nodes', 'CK_Sun in Sign', 'CK_Sign as Spherical Wedge', 'CK_Centrality of Earth', 'CK_Visibility of Half of the Sky from the Central Earth', 'CK_08 Spheres', 'CK_Sphericity of the Water Element', 'CK_Heliacal Rising and Setting', 'CK_Rising and Setting Times at Different Locations', 'CK_Parallels', 'CK_Mercury Lines and Motion', 'CK_Definition of Sphere by Euclid', 'CK_Distances between Small Circles', 'CK_Circles of Natural Days ', 'CK_Chronical Rising and Setting', 'CK_Sun Orbit', 'CK_Isoperimetry', 'CK_Measurements of the Earth', 'CK_Pyramid of a Sign', 'CK_Negligible Dimensions of the Earth', 'CK_Colures', 'CK_Motion of the Eighth Sphere', 'CK_Daily Rotation of the Firmament', 'CK_Lunar Eclipse', 'CK_Circles of Equant Deferent Epicycle', 'CK_Relations between Arcs of the Zodiac and the Equinoctial', 'CK_Multiple Celestial Circles', 'CK_Five Zones', 'CK_Globe', 'CK_Right and Oblique Sphere', 'CK_Ecumene Conception', 'CK_Sun Lines and Motion', 'CK_Terrestrial Coordinates', 'CK_Visibility of Stars from Varied Locations', 'CK_Relation Between the Spheres of Water and Earth ', 'CK_Sphere Sliced by the Signs', 'CK_10 Spheres', 'CK_Seven Climate Zones', 'CK_Apparent Size of Stars', 'CK_Solar Eclipse', 'CK_Introduction to Geometry', 'CK_09 Spheres', 'CK_Terraqueous Globe', 'CK_Terrestrial Maps', 'CK_Lunar Orbit', 'CK_Circles of Natural Days', 'CK_Structure of the Sublunar World', 'CK_Sphericity of the Earth', 'CK_Positions of the Zenith', 'CK_Earth and Cosmos', 'CK_Refraction', 'CK_Sun Proportional Minutes', 'CK_Lunar Phases', 'CK_Zodiac', 'CK_Venus Lines and Motion', 'CK_Horizon', 'CK_Definition of Sphere by Theodosius']
# Count: 68
#
# Other Keywords:
# ['MTK_Isoperimetry_Group_01', 'MTK_Five Zones_Group_01', 'MVK_Pictorial_Diagrams', 'MTK_Terraqueous Globe_Group_02', 'MTK_Lunar Eclipse_Group_09', 'MTK_Terraqueous Globe_Group_03', 'MTK_Sun in Sign_Group_01', 'MTK_Solar Eclipse_Group_08', 'VK_Diagram', 'MTK_Sun Orbit_Group_06', 'MTK_Solar Eclipse_Group_03', 'VK_Material_Representation', 'MTK_Sign as Spherical Wedge_Group_01', 'MTK_Sphere Sliced by the Signs_Group_01', 'Ger_De Tribus Superioribus', 'MTK_Sun Orbit_Group_02', 'MTK_Centrality of Earth_Group_02', 'MTK_Circles of Equant Deferent Epicycle_Group_01', 'MTK_Populated Earth_Group_04', 'MTK_Globe_Group_01', 'MTK_Visibility of Stars from Varied Locations_Group_01', 'MTK_Definition of Sphere by Euclid_Group_03', 'Per_De declinatione et latitudine', 'MTK_Lunar Nodes_Group_02', 'MTK_Cosmic Rising and Setting_Group_02', 'MTK_08 Spheres_Group_02', 'MTK_Right and Oblique Sphere_Group_01', 'MTK_Structure of the Sublunar World_Group_01', 'MTK_Solar Eclipse_Group_10', 'MVK_Others', 'MTK_Negligible Dimensions of the Earth_Group_02', 'Per_De Sole', 'MTK_Elevation of the Pole_Group_01', 'VK_Three Dimensional Shapes', 'MTK_Visibility of Half of the Sky from the Central Earth_Group_01', 'MTK_Horizon_Group_01', 'VK_Illustration', 'MTK_Positions of the Zenith_Group_01', 'VK_Basic geometric shapes', 'MTK_Positions of the Zenith_Group_02', 'Per_De passionibus planetarum diversis', 'MTK_Daily Rotation of the Firmament_Group_04', 'MTK_Refraction_Group_02', 'MTK_Ascensions in the Right and Oblique Sphere_Group_01', 'MTK_Lunar Eclipse_Group_02', 'MTK_Colures_Group_02', 'MTK_Armillary Sphere_Group_05', 'VK_Material_Representation_in_Context', 'MTK_Chronical Rising and Setting_Group_02', 'MTK_Terraqueous Globe_Group_16', 'MVK_Diagrams', 'MTK_Sphericity of the Heavens_Group_02', 'MTK_Five Zones_Group_04', 'MTK_Seven Climate Zones_Group_01', 'MTK_Armillary Sphere_Group_02', 'MTK_Lunar Eclipse_Group_03', 'MTK_Sun Orbit_Group_05', 'MTK_Positions of the Zenith_Group_05', 'MTK_Terraqueous Globe_Group_06', 'MTK_Four Solstices_Group_01', 'MVK_Pictorial_Illustrations', 'MTK_Terraqueous Globe_Group_04', 'MTK_10 Spheres_Group_01', 'MTK_Sphericity of the Water Element_Group_08', 'MTK_Circles of Natural Days_Group_02', 'MTK_Sphericity of the Earth_Group_02', 'MTK_Definition of Sphere by Euclid_Group_05', 'MTK_Pyramid of a Sign_Group_01', 'MTK_Sphericity of the Water Element_Group_04', 'MTK_Lunar Eclipse_Group_01', 'MTK_Circles of Natural Days_Group_01', 'MTK_Sphericity of the Water Element_Group_01', 'MTK_Armillary Sphere_Group_06']
# Count: 73

# %%
# Split keywords by ';' and explode to create one row per keyword
df['keywords'] = df['keywords'].str.split(';')
keyword_df = df.explode('keywords')

# Select relevant columns and drop duplicates to get unique keywords with associated images
keyword_df = keyword_df[['keywords', 'images', 'year', 'place', 'part_type']].drop_duplicates()

# %%
keyword_df
# Out:
#                                                 keywords  \
# 0      CK_Relations Between the Spheres of the Sun an...
# 0                                           MVK_Diagrams
# 1                                 MVK_Pictorial_Diagrams
# 1                                          CK_08 Spheres
# 1                                   CK_Terraqueous Globe
# ...                                                  ...
# 21179                             MVK_Pictorial_Diagrams
# 21179                          MTK_Lunar Phases_Group_06
# 21180                        MVK_Pictorial_Illustrations
# 21180                      SK_4.4 Cause of lunar eclipse
# 21180                                   CK_Lunar Eclipse
#
#                                                   images  year       place  \
# 0      http://devmeta.sphaera.mpiwg-berlin.mpg.de/res...  1550  Wittenberg
# 0      http://devmeta.sphaera.mpiwg-berlin.mpg.de/res...  1550  Wittenberg
# 1      http://devmeta.sphaera.mpiwg-berlin.mpg.de/res...  1561       Padua
# 1      http://devmeta.sphaera.mpiwg-berlin.mpg.de/res...  1561       Padua
# 1      http://devmeta.sphaera.mpiwg-berlin.mpg.de/res...  1561       Padua
# ...                                                  ...   ...         ...
# 21179  http://devmeta.sphaera.mpiwg-berlin.mpg.de/res...  1582     Antwerp
# 21179  http://devmeta.sphaera.mpiwg-berlin.mpg.de/res...  1582     Antwerp
# 21180  http://devmeta.sphaera.mpiwg-berlin.mpg.de/res...  1582     Antwerp
# 21180  http://devmeta.sphaera.mpiwg-berlin.mpg.de/res...  1582     Antwerp
# 21180  http://devmeta.sphaera.mpiwg-berlin.mpg.de/res...  1582     Antwerp
#
#             part_type
# 0        adaption_100
# 0        adaption_100
# 1      influenced_100
# 1      influenced_100
# 1      influenced_100
# ...               ...
# 21179  influenced_100
# 21179  influenced_100
# 21180  influenced_100
# 21180  influenced_100
# 21180  influenced_100
#
# [79443 rows x 5 columns]

# %%
# Split into SK_df, CK_df, and other_keywords
SK_df = keyword_df[keyword_df['keywords'].str.startswith('SK_')]
CK_df = keyword_df[keyword_df['keywords'].str.startswith('CK_')]
other_keywords = keyword_df[~keyword_df['keywords'].str.startswith(('SK_', 'CK_'))]

# %%
SK_df
# Out:
#                             keywords  \
# 4       SK_2.8 Extended Uses of Sign
# 6       SK_2.8 Extended Uses of Sign
# 9              SK_1.2 Sphere Divided
# 10          SK_3.19 The Seven Climes
# 11     SK_4.4 Cause of lunar eclipse
# ...                              ...
# 21173          SK_3.10 Day and Night
# 21174  SK_4.4 Cause of lunar eclipse
# 21174  SK_4.5 Cause of solar eclipse
# 21176  SK_4.4 Cause of lunar eclipse
# 21180  SK_4.4 Cause of lunar eclipse
#
#                                                   images  year    place  \
# 4      http://devmeta.sphaera.mpiwg-berlin.mpg.de/res...  1561    Padua
# 6      http://devmeta.sphaera.mpiwg-berlin.mpg.de/res...  1561    Padua
# 9      http://devmeta.sphaera.mpiwg-berlin.mpg.de/res...  1478   Venice
# 10     http://devmeta.sphaera.mpiwg-berlin.mpg.de/res...  1478   Venice
# 11     http://devmeta.sphaera.mpiwg-berlin.mpg.de/res...  1478   Venice
# ...                                                  ...   ...      ...
# 21173  http://devmeta.sphaera.mpiwg-berlin.mpg.de/res...  1582  Antwerp
# 21174  http://devmeta.sphaera.mpiwg-berlin.mpg.de/res...  1582  Antwerp
# 21174  http://devmeta.sphaera.mpiwg-berlin.mpg.de/res...  1582  Antwerp
# 21176  http://devmeta.sphaera.mpiwg-berlin.mpg.de/res...  1582  Antwerp
# 21180  http://devmeta.sphaera.mpiwg-berlin.mpg.de/res...  1582  Antwerp
#
#             part_type
# 4      influenced_100
# 6      influenced_100
# 9                 100
# 10                100
# 11                100
# ...               ...
# 21173  influenced_100
# 21174  influenced_100
# 21174  influenced_100
# 21176  influenced_100
# 21180  influenced_100
#
# [15908 rows x 5 columns]

# %%
# Extract the numeric part after 'SK_' and convert to floats
SK_df.loc[:, 'number'] = SK_df['keywords'].str.extract(r'SK_(\d+\.\d+)').astype(float)

# Sort SK_df by the extracted numeric values
SK_df = SK_df.sort_values('number').drop(columns='number')

# %%
SK_df
# Out:
#                                keywords  \
# 16717             SK_1.1 Sphere defined
# 14997             SK_1.1 Sphere defined
# 8300              SK_1.1 Sphere defined
# 10777             SK_1.1 Sphere defined
# 10776             SK_1.1 Sphere defined
# ...                                 ...
# 20837  SK_Maurolico Sundial Three Books
# 20838  SK_Maurolico Sundial Three Books
# 20854               SK_Geom Speculative
# 20862                       SK_Paratext
# 21100               SK_Geom Speculative
#
#                                                   images  year       place  \
# 16717  http://devmeta.sphaera.mpiwg-berlin.mpg.de/res...  1591  Wittenberg
# 14997  http://devmeta.sphaera.mpiwg-berlin.mpg.de/res...  1559      Venice
# 8300   http://devmeta.sphaera.mpiwg-berlin.mpg.de/res...  1578        Lyon
# 10777  http://devmeta.sphaera.mpiwg-berlin.mpg.de/res...  1604       Siena
# 10776  http://devmeta.sphaera.mpiwg-berlin.mpg.de/res...  1604       Siena
# ...                                                  ...   ...         ...
# 20837  http://devmeta.sphaera.mpiwg-berlin.mpg.de/res...  1575      Venice
# 20838  http://devmeta.sphaera.mpiwg-berlin.mpg.de/res...  1575      Venice
# 20854  http://devmeta.sphaera.mpiwg-berlin.mpg.de/res...  1593     Antwerp
# 20862  http://devmeta.sphaera.mpiwg-berlin.mpg.de/res...  1555     Antwerp
# 21100  http://devmeta.sphaera.mpiwg-berlin.mpg.de/res...  1582     Antwerp
#
#             part_type
# 16717  influenced_100
# 14997           other
# 8300     adaption_100
# 10777    adaption_100
# 10776    adaption_100
# ...               ...
# 20837           other
# 20838           other
# 20854  influenced_100
# 20862           other
# 21100    adaption_100
#
# [15908 rows x 5 columns]

# %%
# Filter keywords that start with 'SK' and have a number
sk_with_number = keyword_df[keyword_df['keywords'].str.match(r'SK_\d+\.\d*')].copy()

# Count unique images for each SK keyword
sk_with_number['unique_images_count'] = sk_with_number.groupby('keywords')['images'].transform('nunique')

# Select relevant columns for final output
sk_results = sk_with_number[['keywords', 'unique_images_count']].drop_duplicates()

# Extract the numeric part after 'SK_' and convert to float for sorting
sk_results[['integer_part', 'decimal_part']] = sk_results['keywords'].str.extract(r'SK_(\d+)\.(\d+)').astype(float)

# Sort by the extracted numeric values
sk_results = sk_results.sort_values(by=['integer_part', 'decimal_part']).drop(columns=['integer_part', 'decimal_part'])

# %%
sk_results
# Out:
#                                                 keywords  unique_images_count
# 23                                 SK_1.1 Sphere defined                  712
# 9                                  SK_1.2 Sphere Divided                  804
# 26                              SK_1.3 The Four Elements                  116
# 149                                   SK_1.4 The Heavens                   49
# 27                                SK_1.5 Their movements                  292
# 80     SK_1.6 Revolution of the heavens from east to ...                   74
# 28                          SK_1.7 The Heavens Spherical                  764
# 29                               SK_1.9 The earth sphere                  188
# 30                  SK_1.11 Surface of the sea spherical                  325
# 31                             SK_1.13 The earth central                  334
# 31              SK_1.14 And a Mere Point in the universe                  300
# 58          SK_1.16 measuring the earth’s circumference                   405
# 3306         SK_1.16 measuring the earth’s circumference                   27
# 1247                                SK_1.17 the diameter                  137
# 32                              SK_2.1 celestial circles                  296
# 63                                SK_2.2 The Equinoctial                  212
# 3809                      SK_2.3 The Two Movements Again                    6
# 63                      SK_2.4 The north and south poles                  100
# 88                                     SK_2.5 The Zodiac                  178
# 88                               SK_2.6 The Twelve Signs                   69
# 88                                   SK_2.7 The Ecliptic                   30
# 4                           SK_2.8 Extended Uses of Sign                  509
# 91                                        SK_2.9 Colures                  200
# 342                                 SK_2.10 The Meridian                  166
# 77                                   SK_2.11 The Horizon                  353
# 34                         SK_2.12 Elevation of the Pole                  232
# 164              SK_2.13 Tropics of Cancer and Capricorn                  106
# 166                 SK_2.14 Arctic and Antarctic Circles                   87
# 616    SK_2.15 (the maximum declination of the sun = ...                   90
# 343                                              SK_2.16                    8
# 35                                SK_2.17 The Five Zones                  468
# 36               SK_3.1 Rising and settings of the signs                   37
# 95                                  SK_3.2 Cosmic rising                   39
# 95                                 SK_3.3 Cosmic setting                   32
# 95                     SK_3.4 Chronic rising and setting                   32
# 95                    SK_3.5 Heliacal Rising and Setting                   69
# 37                               SK_3.6 Right Ascensions                  274
# 346                            SK_3.7 Oblique Ascensions                  307
# 38                             SK_3.8 Inequality of Days                  148
# 98                            SK_3.9 Movement of the Sun                  635
# 2035                               SK_3.10 Day and Night                  198
# 12210              SK_3.11 Right and Oblique  Ascensions                    6
# 39                       SK_3.12 Dwellers at the equator                   61
# 40      SK_3.13 Between the Equator and Tropic of Cancer                   88
# 40                       SK_3.14 At the Tropic of Cancer                  245
# 40     SK_3.15 Between the Tropic and the Arctic Circles                  157
# 40                          SK_3.16 At the arctic circle                  252
# 40     SK_3.17 Between the Arctic circle and the Nort...                   27
# 40                             SK_3.18 at the north pole                  133
# 10                              SK_3.19 The Seven Climes                  238
# 1222                                   SK_3.27 Beyond it                   13
# 42                            SK_4.1 Movement of the sun                  370
# 107    SK_4.2 Of the other planets: Equant, Deferent,...                  543
# 22             SK_4.3 Stationary, direct, and retrograde                  267
# 11                         SK_4.4 Cause of lunar eclipse                  789
# 11                         SK_4.5 Cause of solar eclipse                  303

# %%
# Create a DataFrame for pie plot
pie_data = sk_with_number.groupby('keywords')['unique_images_count'].sum().reset_index()

# Plotting the pie chart
plt.figure(figsize=(8, 6))
plt.pie(pie_data['unique_images_count'], labels=pie_data['keywords'], autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Unique Images for SK Keywords with Numbers')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()
